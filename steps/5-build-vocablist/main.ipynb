# %%
import spacy
import json
from tqdm import tqdm
from collections import Counter
import pathlib
import glob
import numpy as np
import pandas as pd

# %%
nlp = spacy.load("en_core_web_sm")

# %%
with open('../../data/wordlist-sources/1_2020_2.json', 'r') as f:
    data = json.load(f)
data
# Out:
# ["Julia, we're considering you for the regional sales director position. You'd still work here at the head office, but it'd mean having to travel more.",
#  "Ah . . . that might be a problem. My kids are still young, and you know that I'm a single mother, so I can't be gone too much.",
#  "Right. We realize that, but there may be a way to cut down on the trips. We've been trying out video conferencing, and so far, so good.",
#  "Then I'd certainly be interested.",
#  'By transferring the woman to a regional office.',
#  "By getting someone to help with the woman's children.",
#  'By offering the woman a different position.',
#  "Gary, it's me. I'm afraid I have to work late again.",
#  "Again? That's the third time this week! When do you think you'll get home?",
#  "Probably around 9. Listen, Clive's baseball practice ends at 8:30. Can you pick him up?",
#  "Well, I'm supposed to be giving your mom a ride to the airport.",
#  "Ah, I forgot. Well, I guess he'll just have to wait for a bit until I get there.",
#  "He'll understand. And I'll pick up some dinner for us on my way back.",
#  'Leave the office early to get Clive.',
#  'Drive her mother to the airport.',
#  'Buy dinner on her way home.',
#  "Hey, Steve. Wasn't that board meeting really frustrating?",
#  'Yes! Margaret dominated again. Her constant sniping at others and negativity about fresh ideas is hampering the organization.',
#  'Should we try talking to her?',
#  "You think she'll listen? We only joined the board a few months ago.",
#  "True, but we can't just sit back and do nothing. Let's sound out the president and see if he can encourage her to step down.",
#  "That's a bit drastic. We should rally the other board members around us first.",
#  "You're right. Then maybe we can push for her resignation!",
#  'Threaten to resign from the board.',
#  'Advise the president to step down.',
#  'Talk with Margaret about her attitude.',
#  'Did you hear that Jason Lind is going to direct a new cable TV series?',
#  "Isn't he a movie director?",
#  'Yes. And a very good one, too.',
#  'I wonder why he decided to go into TV.',
#  'A lot of film actors have been successful in hit TV shows recently. I suppose it was just a matter of time before directors tried to make the same shift.',
#  "Well, if his TV debut is anything like his movies, it'll be fantastic.",
#  'He has little experience directing movies.',
#  'He got poor reviews for his latest movie.',
#  'He could not get good actors for his TV show.',
#  'Look at this TV ad, George. That vegetable cutter can cut, slice, and dice just about anything.',
#  'If it really worked, it would be selling well in regular stores.',
#  'Why are you always such a cynic?',
#  'My father bought something like that once, but he could never get it to work.',
#  'That was years ago. Things are more advanced now.',
#  'Only the promotion methods! But if you really want it, get it.',
#  "No, because if it breaks, I'll never hear the end of it.",
#  'The man will not let the woman buy the product.',
#  "The woman's father has the same product.",
#  'The woman prefers to shop at regular stores.',
#  "See you later, Kay. I'm off to the gym.",
#  'Since when did you become Mr. Fitness?',
#  'I got this great deal at the new gym in the malla one-year membership for only 300 dollars.',
#  "And you really think that's a good deal?",
#  'Well, yeah. All the equipment is state-of-the-art, and they have four Jacuzzis.',
#  'You know the place across the street from my office? With the Olympic-sized swimming pool? I got two years there for that price.',
#  'Great. Now you tell me.',
#  'The equipment is outdated.',
#  'The man needs to save more money.',
#  'The man should not exercise so much.',
#  "Hey, Annie! Long time, no see. How's art school going?",
#  'Pretty well, Mark. I switched my major from fine art to design, and I just got accepted as an intern at a furniture company.',
#  'Great! But I thought your real love was sculpture.',
#  'It is, but I had to face reality. I can make a much better living following this career path.',
#  "Do you think it'll satisfy you enough to do it long term?",
#  "I guess I'll see how the internship goes.",
#  'She always wanted to design furniture.',
#  'She is no longer interested in sculpture.',
#  'Fine art was more challenging than she thought.',
#  "I'm finished studying. Let's grab lunch.",
#  'But I still have to finish my psychology paper.',
#  "Come on, take a break. We've been at it all morning.",
#  "It'll only take me another hour or so. I have to get it done today.",
#  "That's what happens when you put it off until the last minute!",
#  'I know, I know. Will I see you later?',
#  "Yeah, as long as you're still planning to go to Jim's party tonight.",
#  "Wouldn't miss it!",
#  'He does not have time to go to lunch.',
#  "The woman should not go to Jim's party.",
#  'He cannot meet the woman later.',
#  "Lucas, don't forget Judy's expecting an answer to whether we're going to her daughter's dance recital.",
#  "I just can't see why we have to drive two hours each way to spend an entire Saturday doing that. We were at her son's birthday party just a couple of weeks ago.",
#  "I'm with you, but that's just the way she is. You know she's really big on family and loves having us visit.",
#  "Well, we have to let her know somehow that we can't just drop everything whenever a nephew or niece has a birthday or soccer game.",
#  'She only does it because she wants to include us in things.',
#  "I know, and I appreciate that. She's the best sister-in-law you could ask for. But we've got to draw the line somewhere.",
#  "Fair enough. We just have to figure out how to wriggle out of this. Maybe I could remind her about my migraines and tell her they're forcing us to limit our trips.",
#  "Now, that's an idea. It's not an outright lie, either, although they haven't been that bad recently.",
#  "Well, I'll send her an e-mail and let her know. But she won't be happy about it.",
#  "His wife's sister expects too much.",
#  'His wife should make the trip alone.',
#  "His wife may hurt Judy's feelings.",
#  'Well, guys, we need to discuss how to shut down our Hong Kong office next year with minimal impact.',
#  "That's going to be tough. Word has already leaked out, and employees there are beginning to panic.",
#  "That's the last thing we need. Morale will plummet.",
#  "Well, the Japanese staff will be transferred to other offices, most to locations in Japan, but it's the local Hong Kong staff I'm worried about.",
#  'Agreed. If we just lay them off, our reputation could be irreparably damaged.',
#  "Well, we can transfer a handful of them to our Shenzhen office. For those who aren't willing, we should at least provide generous severance packages. Protecting the company's image as a good employer is most important.",
#  'Preventing the Japanese staff from quitting.',
#  'Preventing employees from suing the company.',
#  'Finding a local company to take over current clients.',
#  'They have helped students avoid high debt.',
#  'They are only available to a few students.',
#  'They focus primarily on the highest-paying jobs.',
#  'They do not affect employment rates.',
#  'They have helped students avoid high debt.',
#  "They may limit participants' job options.",
#  "They may limit participants' job options.",
#  'Employers take unfair advantage of participants.',
#  'They make it harder for high school students to graduate.',
#  'High school students are too young to decide on a career.',
#  'They are less reliant on fossil fuels.',
#  'They are not harmful to the ozone layer.',
#  'They are made by recycling old petroleum-based products.',
#  'They are less reliant on fossil fuels.',
#  'They are easier to turn into useful products.',
#  'The methane they produce harms recycling systems.',
#  'They can only be reused once.',
#  'They require special processing to be recycled.',
#  'The methane they produce harms recycling systems.',
#  'The plants used to make them are disappearing.',
#  'She would not be able to complete the assigned task.',
#  'She would quit the US Navy in protest.',
#  'She would not be able to complete the assigned task.',
#  'She would damage the computer system.',
#  'She would not need to ask for a later deadline.',
#  'Ensuring that submarines would be safer to operate.',
#  'Convincing the US government it needed fewer warships.',
#  'Ensuring that submarines would be safer to operate.',
#  'Discovering a new way to fight sea battles.',
#  'Changing how modern naval vessels are designed.',
#  'The females are sometimes eaten by the males.',
#  'They lay more eggs than any other marine species.',
#  'The females are larger than the males.',
#  'They change sex to aid reproduction.',
#  'The females are sometimes eaten by the males.',
#  'By keeping algae from sinking.',
#  'By converting carbon into waste matter.',
#  'By absorbing CO directly from the air.',
#  'By helping algae reproduce more quickly.',
#  'By keeping algae from sinking.',
#  'Their lungs had been affected by air pollution.',
#  'Their lungs were larger than previously believed.',
#  'They had developed rare types of cancer.',
#  'Their lungs had been affected by air pollution.',
#  'They had been treated for diseases that are common today.',
#  'They affected a wide range of people in ancient Egypt.',
#  'They especially affected wealthy Egyptians.',
#  'They played an important role in preserving mummies.',
#  'They were first identified by ancient Egyptians.',
#  'They affected a wide range of people in ancient Egypt.',
#  'the replication studies were carried out by researchers with better academic reputations than the researchers who had published the original studies.',
#  'it attempted to address accusations that had been made by people who believed that earlier replication studies had not been conducted properly.',
#  'around half of the original experiments that were chosen to be performed again had not been the subject of any previous replication studies.',
#  'it focused only on replicating the results of studies that the original researchers had expressed uncertainty about when they were first conducted.',
#  'Although more attention is paid to the practice, it is actually much less serious than more common problems, such as fraud and bias in journals.',
#  'Since it is so hard to be certain whether a "p-value" is accurate, it is almost impossible to prove that a researcher is guilty of p-hacking.',
#  'Although the practice is harmful to the validity of research, manipulating data is considered by many in the field of psychology to be acceptable.',
#  'Since journals have actually been proven to encourage the practice, they should not pretend that it is not extremely common in the field of psychology.',
#  'By increasing awareness of the need for novel ideas in psychology, the crisis is likely to lead to the development of various new theories.',
#  'The studies that cause doubt about the original psychology experiments are themselves an indicator that psychology experiments can be reliable.',
#  "By casting doubt on famous researchers' work, it could create opportunities for lesser-known researchers to get unusual findings published.",
#  'The results of many studies that were once discredited have since been shown to be among the most reliable in the field of psychology.',
#  'Reproducibility is a cornerstone of science, yet a growing chorus of researchers have claimed that numerous experiments, even ones carried out by esteemed psychologists and reported in prestigious journals, cannot be successfully replicated. One notable example is a widely cited piece of psychological research claiming that completing word puzzles designed to evoke images associated with old age caused the experiment\'s subjects to walk more slowly afterward. However, it has never been successfully confirmed by other researchers. Defenders of studies that came under fire when they could not be replicated, however, presented a host of possible explanations for the inconsistencies, alleging that the researchers who attempted the replications lacked the necessary competence, or claiming that sample sizes in the follow-ups had been insufficient. In response, a project was undertaken under the direction of University of Virginia researcher Brian Nosek in the 2010s that put nearly 100 celebrated psychology studies to the test by attempting to reproduce them. The results were startling: only about half the studies investigated made the grade, highlighting what has been dubbed psychology\'s "replication crisis." While there have been cases of outright fraud and complaints that journals tend to favor studies that confirm the researchers\' hypothesis, perhaps the most disturbing trend revealed in the wake of Nosek\'s study is what is known as "p-hacking." This is coined from the statistical term "p-value," which is calculated by researchers to show the probability that their experimental results are actually being produced by the effect they are studying rather than by random chance or some other factor. In their quest to obtain an acceptable p-value, researchers have been accused of omitting undesirable data, choosing statistical tests that are more likely to confirm their desired results, and being selective about which observations are compared with each other. In one survey, over 40 percent of psychology researchers admitted to some form of p-hacking, and, astonishingly, the majority felt their research methods were defensible because they were carrying out practices that are well established, and even taught, in the profession. This is what makes p-hacking so insidious. The combined effect of fraud, publication bias, and p-hacking has caused many to question the validity of psychology studies appearing in well-known textbooks and journals. While some researchers worry the crisis will reduce their field to the status of pseudoscientific nonsense, others have noted that it could be beneficial. The follow-up testing conducted in Nosek\'s study that brought the validity of psychological research into question actually demonstrates that lab experiments, when conducted to the highest standards of practice, are a valid method of studying human behavior. In addition, the reproduction of some original findings helps validate the theories behind them. Nosek says studies like the ones in his project are usually overlooked because "the incentives for individual scientists prioritize novelty over replication." He suggests that enticements such as publication and funding should be geared equally toward rewarding both new discoveries and the substantiation of previous ones.',
#  "the actions of Germany's chancellor immediately following the signing of the armistice caused his relationship with the army to worsen greatly.",
#  "errors made by German commanders in the war's early days weakened the country's bargaining position when the Treaty of Versailles was proposed.",
#  "enemy propaganda that had been intended to influence German civilians instead caused the military to turn against the country's government.",
#  'Despite many people thinking it did not mean Germany had to pay for damage caused during the war, it had other economic effects that were even more serious.',
#  'It was seen as severely punishing Germany for starting the war, but it mostly gave a legal basis for relatively favorable terms.',
#  "Though the treaty came to be blamed for Germany's problems, it was really the Nazis themselves who were causing them.",
#  "The ocean current in the area of the islands carried large amounts of nitrates to the guano mounds, making them resistant to the effects of the islands' arid air.",
#  'The guano that was richest in nitrates was difficult to access because it was trapped in the inner sections of the huge mounds that had been formed.',
#  'Indigenous peoples who inhabited the area did not realize guano had potential as a fertilizer until the seabirds that produced it had already disappeared.',
#  "Peruvian businesses spreading false rumors about guano's benefits and taking advantage of British farmers' desperation to boost their failing crops.",
#  'a desire to revitalize farmland damaged by excessive amounts of human waste accumulating in rural areas that lacked the resources to manage it.',
#  'trends toward urban farming that had developed due to the highly wasteful farming practices carried out in rural areas.',
#  'Negotiations with Peru for financial assistance to deal with shipping and marketing problems were taking longer than they had initially expected.',
#  'The merchants were upset because the Peruvian government would only pay them their commission at times that coincided with the receipt of loans from abroad.',
#  'Taking the time to negotiate guano sale prices with overseas buyers was essential for the merchants, allowing them to maximize their profits.',
#  'The high cost of extracting guano from the Chincha Islands caused the government to mismanage its budget in ways that hurt domestic industries.',
#  'The boost in its ability to obtain credit that had resulted from its foreign partnerships caused it to take on an excessive amount of debt.',
#  "The inefficiency of forcing Peruvian and British firms to cooperate with each other caused a significant decline in the industry's profits.",
#  'When the fighting ended, German chancellor Friedrich Ebert made the deceptive declaration that German troops had returned "unconquered from the field of battle." Though intended to maintain national pride, this statement contributed significantly to the widespread delusions about the result of the war, and these helped give rise to a betrayal myth known as the "stab in the back." According to this notion, since Germany had not been defeated militarily, it must have been betrayed from within. As a result, nationalists were able to blame labor organizations, socialists, and the country\'s Jewish population for the seemingly disadvantageous terms the Treaty of Versailles imposed on Germany. The most infamous section of the treaty was Article 231, commonly known as the "war guilt clause." It established Germany\'s responsibility for its actions as a basis for surrendering territory and making financial reparations. Nationalists, bitter from the German defeat, however, condemned it and claimed the reparation costs demanded by the Triple Entente were so excessive that they impoverished the nation. When read in context, though, it becomes evident that, rather than condemning Germany for the outbreak of hostilities, Article 231 primarily served to establish that Germany was legally obligated to abide by the demands for reparations laid out in other articles of the treaty, one of which actually limited Germany\'s responsibility mainly to paying for damage incurred by civilians. The clause is therefore more accurately viewed as part of a concession to Germany by the victors. When Adolf Hitler\'s Nazi Party took power in the 1930s, it claimed Germany, as a victim of the terms imposed by the Treaty of Versailles, had become an international outcast. Playing on the notion of Article 231 as a war guilt clause, the Nazis fanned the flames of German resentment. Their claim was adopted in many historical narratives and taken as fact by influential individuals, like Britain\'s wartime prime minister David Lloyd George, who joined in laying much of the blame for Germany\'s renewed postwar militarism on the legacy of the Treaty of Versailles. In fact, this interpretation is still commonly cited as a key cause of World War II. It can be argued, however, that the Nazis had it entirely backwards. Their illegal rearmament and seizure of territory, which violated the Treaty of Versailles, were the true impetus for Germany\'s exclusion from the international community. Perhaps it is time to relegate Article 231\'s label as the "war guilt clause" to simply a footnote of history.',
#  'When Peru achieved its independence from Spain in the 1820s, it was beset by economic woes. The hard-fought war for freedom had damaged the trade in silver between the two countries, leading to the collapse of the silver mines that had been the backbone of Peru\'s economy. The conflict had also put the country in massive debt to British bankers, from whom the Peruvian government had borrowed heavily to fund its war effort. Struggling unsuccessfully to develop its economy for two decades following independence, Peru was eventually handed a glimmer of hope in the form of an unlikely resource: seabird manure. This waste product, known as guano, had accumulated in enormous mounds on the Chincha Islands off the country\'s coast. Its shores, drenched in nourishing waters flowing from the Pacific Ocean and teeming with various marine species, attracted a large predatory bird population. The combination of cool ocean currents and warm tropical air created an exceedingly arid environment, ensuring that the abundant nutrients naturally present in the guano were not dispersed by precipitation. The particularly high nitrogen content in guano, in fact, is what made the waste material an ideal fertilizer. Indigenous peoples had been using the guano sustainably as such for centuries, carefully timing its extraction from the islands so as not to disturb the seabird populations and penalizing anyone who harmed the birds during mating season with death. Guano was not widely appreciated in Europe, however, until 1838, when two businessmen in Peru sent samples to Britain, where farmers soon noted its effect on depleted soil. The surge in demand for food caused by an enormous population boom had led to unsustainable farming practices, while the population shift from rural to urban areas driven by industrialization meant human waste wound up in cities rather than being returned to farmland to be used as fertilizer, as had previously been the case. Guano proved a magic bullet to invigorate the degraded soil. By 1841, trade in the product between Peru and Britain was well underway, ushering in the Guano Age. The Peruvian government enjoyed a monopoly over the Chincha Islands\' guano, but the country lacked both the capital and the expertise to effectively manage international shipping and sales. Consequently, these were consigned to British merchants, who received a substantial commission for their efforts. Furthermore, payment was not rendered to the Peruvian government until transactions were finalized, a rather lengthy process considering that loading one ship could take well over a month. Rampant corruption among the ruling class only made matters worse, and although much money had been poured into various public projects, little had been spent on efforts to diversify and stabilize the economy in the long term. The guano-driven "prosperity" Peru enjoyed eventually proved painfully finite. Ravaged by the guano trade, the Chincha Islands\' once-gigantic mounds of manure that had formed over thousands of years were almost depleted by the 1870s, and the seabirds relied on for replenishing the supply had been largely driven away or killed after decades of incessant extraction. The shortage spelled economic disaster for Peru, whose lack of economic prudence left it no better off after the guano boom than it had been before it. Swedish historian Magnus Mrner, echoing the opinion of many scholars, stated that, for Peru, "guano wealth was, on the whole, a developmental opportunity missed."',
#  "the actions of Germany's chancellor immediately following the signing of the armistice caused his relationship with the army to worsen greatly.",
#  "errors made by German commanders in the war's early days weakened the country's bargaining position when the Treaty of Versailles was proposed.",
#  "enemy propaganda that had been intended to influence German civilians instead caused the military to turn against the country's government.",
#  'Despite many people thinking it did not mean Germany had to pay for damage caused during the war, it had other economic effects that were even more serious.',
#  'Although it was seen as severely punishing Germany for starting the war, it mostly gave a legal basis for terms that were relatively favorable for the country.',
#  'Causing people to ignore Article 231 and focus on other parts of the treaty helped the Nazis negotiate the return of territory that had been lost in the war.',
#  "Though the treaty came to be blamed for Germany's problems, it was really the Nazis themselves who were causing them.",
#  "The ocean current in the area of the islands carried large amounts of nitrates to the guano mounds, making them resistant to the effects of the islands' arid air.",
#  'The guano that was richest in nitrates was difficult to access because it was trapped in the inner sections of the huge mounds that had been formed.',
#  'Indigenous peoples who inhabited the area did not realize guano had potential as a fertilizer until the seabirds that produced it had already disappeared.',
#  "Peruvian businesses spreading false rumors about guano's benefits and taking advantage of British farmers' desperation to boost their failing crops.",
#  'a desire to revitalize farmland damaged by excessive amounts of human waste accumulating in rural areas that lacked the resources to manage it.',
#  'trends toward urban farming that had developed due to the highly wasteful farming practices carried out in rural areas.',
#  'The high cost of extracting guano from the Chincha Islands caused the government to mismanage its budget in ways that hurt domestic industries.',
#  'The boost in its ability to obtain credit that had resulted from its foreign partnerships caused it to take on an excessive amount of debt.',
#  "The end of regulation on guano extraction in the 1870s led wealthy Peruvians to remove much of it for private gain without regard for the seabirds' welfare.",
#  "The inefficiency of forcing Peruvian and British firms to cooperate with each other caused a significant decline in the industry's profits.",
#  'When the fighting ended, German chancellor Friedrich Ebert made the deceptive declaration that German troops had returned "unconquered from the field of battle." Though intended to maintain national pride, this statement contributed significantly to the widespread delusions about the result of the war, and these helped give rise to a betrayal myth known as the "stab in the back." According to this notion, since Germany had not been defeated militarily, it must have been betrayed from within. As a result, nationalists were able to blame labor organizations, socialists, and the country\'s Jewish population for the seemingly disadvantageous terms the Treaty of Versailles imposed on Germany. The most infamous section of the treaty was Article 231, commonly known as the "war guilt clause." It established Germany\'s responsibility for its actions as a basis for surrendering territory and making financial reparations. Nationalists, bitter from the German defeat, however, condemned it and claimed the reparation costs demanded by the Triple Entente were so excessive that they impoverished the nation. When read in context, though, it becomes evident that, rather than condemning Germany for the outbreak of hostilities, Article 231 primarily served to establish that Germany was legally obligated to abide by the demands for reparations laid out in other articles of the treaty, one of which actually limited Germany\'s responsibility mainly to paying for damage incurred by civilians. The clause is therefore more accurately viewed as part of a concession to Germany by the victors. When Adolf Hitler\'s Nazi Party took power in the 1930s, it claimed Germany, as a victim of the terms imposed by the Treaty of Versailles, had become an international outcast. Playing on the notion of Article 231 as a war guilt clause, the Nazis fanned the flames of German resentment. Their claim was adopted in many historical narratives and taken as fact by influential individuals, like Britain\'s wartime prime minister David Lloyd George, who joined in laying much of the blame for Germany\'s renewed postwar militarism on the legacy of the Treaty of Versailles. In fact, this interpretation is still commonly cited as a key cause of World War II. It can be argued, however, that the Nazis had it entirely backwards. Their illegal rearmament and seizure of territory, which violated the Treaty of Versailles, were the true impetus for Germany\'s exclusion from the international community. Perhaps it is time to relegate Article 231\'s label as the "war guilt clause" to simply a footnote of history.',
#  "When Peru achieved its independence from Spain in the 1820s, it was beset by economic woes. The hard-fought war for freedom had damaged the trade in silver between the two countries, leading to the collapse of the silver mines that had been the backbone of Peru's economy. The conflict had also put the country in massive debt to British bankers, from whom the Peruvian government had borrowed heavily to fund its war effort. Struggling unsuccessfully to develop its economy for two decades following independence, Peru was eventually handed a glimmer of hope in the form of an unlikely resource: seabird manure. This waste product, known as guano, had accumulated in enormous mounds on the Chincha Islands off the country's coast. Its shores, drenched in nourishing waters flowing from the Pacific Ocean and teeming with various marine species, attracted a large predatory bird population. The combination of cool ocean currents and warm tropical air created an exceedingly arid environment, ensuring that the abundant nutrients naturally present in the guano were not dispersed by precipitation. The particularly high nitrogen content in guano, in fact, is what made the waste material an ideal fertilizer. Indigenous peoples had been using the guano sustainably as such for centuries, carefully timing its extraction from the islands so as not to disturb the seabird populations and penalizing anyone who harmed the birds during mating season with death. Guano was not widely appreciated in Europe, however, until 1838, when two businessmen in Peru sent samples to Britain, where farmers soon noted its effect on depleted soil. The surge in demand for food caused by an enormous population boom had led to unsustainable farming practices, while the population shift from rural to urban areas driven by industrialization meant human waste wound up in cities rather than being returned to farmland to be used as fertilizer, as had previously been the case. Guano proved a magic bullet to invigorate the degraded soil. By 1841, trade in the product between Peru and Britain was well underway, ushering in the Guano Age. The Peruvian government enjoyed a monopoly over the Chincha Islands' guano, but the country lacked both the capital and the expertise to effectively manage international shipping and sales. Consequently, these were consigned to British merchants, who received a substantial commission for their efforts.",
#  'Rampant corruption among the ruling class only made matters worse, and although much money had been poured into various public projects, little had been spent on efforts to diversify and stabilize the economy in the long term. The guano-driven "prosperity" Peru enjoyed eventually proved painfully finite. Ravaged by the guano trade, the Chincha Islands\' once-gigantic mounds of manure that had formed over thousands of years were almost depleted by the 1870s, and the seabirds relied on for replenishing the supply had been largely driven away or killed after decades of incessant extraction. The shortage spelled economic disaster for Peru, whose lack of economic prudence left it no better off after the guano boom than it had been before it. Swedish historian Magnus Mrner, echoing the opinion of many scholars, stated that, for Peru, "guano wealth was, on the whole, a developmental opportunity missed."']

# %%
def extract_words(text):
    doc = nlp(text)
    words = set()
    for token in doc:
        if token.is_alpha and not token.is_stop:
            words.add(token.lemma_.lower())
    return words

# %%
NOUN_ARTICLES = {"a", "an", "the"} # これは S/O で消す
BE_VERBS = {"am", "is", "are", "was", "were", "'m", "'re", "'s", "be"} # これは S の直後に残す

def to_varient(doc): # 主語を "S" で置換
    new_doc = [] # すべて lemma に変換、単語用

    for i, token in enumerate(doc):
        prev_token = doc[i-1] if i > 0 else None
        prev_inserted = new_doc[-1] if new_doc else None

        if token.dep_ == "nsubj" or token.dep_ == "nsubjpass":
            # S のとき
            if prev_token and prev_token.lemma_.lower() in NOUN_ARTICLES and prev_inserted != "S":
                new_doc.pop()  # 直前の冠詞を削除
            new_doc.append("S")
        elif token.dep_ == 'obj' or token.dep_ == 'dobj' or token.dep_ == 'iobj':
            # O のとき
            if prev_token and prev_token.lemma_.lower() in NOUN_ARTICLES and prev_inserted != "O":
                new_doc.pop()  # 直前の冠詞を削除
            new_doc.append("O")
        elif (prev_inserted == "S" or prev_inserted == 'O') and token.lemma_ in BE_VERBS:
            new_doc.append("be")
        else:
            new_doc.append(token.text)
    return new_doc

vocabs = Counter()
for text in tqdm(data):
    doc = nlp(text)
    words = to_varient(doc)
    for n in range(2, 5):
        ngrams = zip(*[words[i:] for i in range(n)])
        for ngram in ngrams:
            vocabs[ ' '.join(ngram) ] += 1
vocabs
# Out:
# 100%|██████████| 199/199 [00:01<00:00, 146.71it/s]
# Counter({'S be': 122,
#          'O .': 63,
#          ', S': 62,
#          'S had': 51,
#          '. S': 42,
#          'in the': 34,
#          'S of': 31,
#          'O of': 31,
#          'O to': 28,
#          'of the': 25,
#          'had been': 22,
#          'to the': 21,
#          'S had been': 21,
#          'O ,': 20,
#          'O for': 19,
#          ', S be': 19,
#          ', and': 19,
#          'that S': 16,
#          'from the': 15,
#          'O in': 15,
#          'by the': 15,
#          'O and': 13,
#          'S in': 13,
#          '. S be': 12,
#          'O S': 12,
#          '. The': 12,
#          "Germany 's": 12,
#          'S have': 11,
#          "S 'll": 11,
#          'to be': 11,
#          'O from': 11,
#          'as a': 11,
#          'S to': 11,
#          '. "': 11,
#          ', but': 10,
#          'on the': 10,
#          'S can': 10,
#          'S S': 10,
#          'S ,': 10,
#          'of Versailles': 10,
#          'its O': 10,
#          'for the': 9,
#          'but S': 9,
#          ', but S': 9,
#          'and S': 9,
#          ', and S': 9,
#          'Well ,': 9,
#          'S would': 9,
#          'O . S': 9,
#          'the country': 9,
#          'S know': 8,
#          'S could': 8,
#          "'s O": 8,
#          'p -': 8,
#          '" S': 8,
#          "country 's": 8,
#          "the country 's": 8,
#          'the guano': 8,
#          'the Chincha': 8,
#          'Chincha Islands': 8,
#          'the Chincha Islands': 8,
#          'be a': 7,
#          'have to': 7,
#          ', however': 7,
#          'however ,': 7,
#          'known as': 7,
#          'caused S': 7,
#          ', however ,': 7,
#          'caused S to': 7,
#          'the war': 7,
#          'Peruvian S': 7,
#          'S should': 6,
#          'be not': 6,
#          'S be not': 6,
#          '. In': 6,
#          'S made': 6,
#          'for Germany': 6,
#          "for Germany 's": 6,
#          'the islands': 6,
#          'O in the': 6,
#          'as the': 6,
#          'the "': 6,
#          'Article 231': 6,
#          'war guilt': 6,
#          'guilt clause': 6,
#          'as the "': 6,
#          'war guilt clause': 6,
#          'guano ,': 6,
#          'that S be': 5,
#          'S be a': 5,
#          'Well , S': 5,
#          'have been': 5,
#          'S has': 5,
#          'when S': 5,
#          ', as': 5,
#          'O about': 5,
#          'O S be': 5,
#          'O as': 5,
#          'Their S': 5,
#          'been the': 5,
#          '- hacking': 5,
#          'p - hacking': 5,
#          'the field': 5,
#          'field of': 5,
#          'of psychology': 5,
#          'the field of': 5,
#          'O of the': 5,
#          'rather than': 5,
#          'and the': 5,
#          'S in the': 5,
#          'the treaty': 5,
#          'of the treaty': 5,
#          'be still': 4,
#          "ca n't": 4,
#          'S be still': 4,
#          'to a': 4,
#          'with the': 4,
#          'S have to': 4,
#          'be the': 4,
#          'think S': 4,
#          'S be the': 4,
#          'O to the': 4,
#          'O on': 4,
#          'S really': 4,
#          'it .': 4,
#          'S will': 4,
#          'S just': 4,
#          'But S': 4,
#          'than S': 4,
#          'because S': 4,
#          'made by': 4,
#          'not be': 4,
#          'be able': 4,
#          'able to': 4,
#          'be able to': 4,
#          'carried out': 4,
#          'the original': 4,
#          'had not': 4,
#          'not been': 4,
#          'had not been': 4,
#          '. " S': 4,
#          'S of Versailles': 4,
#          'intended to': 4,
#          'did not': 4,
#          'for damage': 4,
#          'war ,': 4,
#          'economic O': 4,
#          'the war ,': 4,
#          ', S had': 4,
#          'of the islands': 4,
#          'Indigenous S': 4,
#          'had O': 4,
#          'S had O': 4,
#          'in rural': 4,
#          'rural areas': 4,
#          'S lacked': 4,
#          'in rural areas': 4,
#          'farming practices': 4,
#          'out in': 4,
#          'the Peruvian': 4,
#          'O from the': 4,
#          'When S': 4,
#          'made the': 4,
#          ', this': 4,
#          'this S': 4,
#          '" war': 4,
#          '. When': 4,
#          'that ,': 4,
#          'the Treaty': 4,
#          'Treaty of': 4,
#          'Versailles ,': 4,
#          ', had': 4,
#          '. Their': 4,
#          'fact ,': 4,
#          'S made the': 4,
#          ', this S': 4,
#          'known as the': 4,
#          'the " war': 4,
#          '" war guilt': 4,
#          "Germany 's O": 4,
#          'the Treaty of': 4,
#          'Treaty of Versailles': 4,
#          'of Versailles ,': 4,
#          'known as the "': 4,
#          'as the " war': 4,
#          'the " war guilt': 4,
#          '" war guilt clause': 4,
#          'the Treaty of Versailles': 4,
#          'to British': 4,
#          'waste S': 4,
#          "Islands '": 4,
#          'for Peru': 4,
#          'Peru ,': 4,
#          'its O from': 4,
#          "Chincha Islands '": 4,
#          'for Peru ,': 4,
#          "the Chincha Islands '": 4,
#          "S 'd": 3,
#          'O for the': 3,
#          'S ca': 3,
#          "S ca n't": 3,
#          "S 've": 3,
#          'O to a': 3,
#          '? S': 3,
#          'S think': 3,
#          'S think S': 3,
#          "think S 'll": 3,
#          "S think S 'll": 3,
#          'back .': 3,
#          'to get': 3,
#          'get O': 3,
#          'ago .': 3,
#          'if S': 3,
#          'be going': 3,
#          'going to': 3,
#          'S be going': 3,
#          'be going to': 3,
#          'S be going to': 3,
#          'to go': 3,
#          ", S 'll": 3,
#          'S got': 3,
#          'would be': 3,
#          'S would be': 3,
#          'be more': 3,
#          'S be more': 3,
#          'let S': 3,
#          "'s S": 3,
#          'O later': 3,
#          'should not': 3,
#          'S should not': 3,
#          'be ,': 3,
#          'had to': 3,
#          'S be ,': 3,
#          'S had to': 3,
#          '. S can': 3,
#          'long term': 3,
#          'put O': 3,
#          'until the': 3,
#          'go to': 3,
#          'O . S be': 3,
#          'be really': 3,
#          'S be really': 3,
#          ', S have': 3,
#          '. S be not': 3,
#          'S may': 3,
#          ', the': 3,
#          "'s O as": 3,
#          'O as a': 3,
#          'to take': 3,
#          'helped S': 3,
#          'to turn': 3,
#          'would not': 3,
#          'S would not': 3,
#          'the males': 3,
#          'males .': 3,
#          'the males .': 3,
#          'marine species': 3,
#          'air .': 3,
#          'Their S be': 3,
#          'had developed': 3,
#          'S had developed': 3,
#          'O S had': 3,
#          'S had not': 3,
#          'S had not been': 3,
#          'S of the': 3,
#          'that the': 3,
#          'problems ,': 3,
#          '" p': 3,
#          'S "': 3,
#          '" p -': 3,
#          'in the field': 3,
#          'field of psychology': 3,
#          'in the field of': 3,
#          'the field of psychology': 3,
#          'O , S': 3,
#          'about the': 3,
#          'S an': 3,
#          'can be': 3,
#          'S can be': 3,
#          'of many': 3,
#          'among the': 3,
#          'S came': 3,
#          'is S': 3,
#          ', "': 3,
#          'O that': 3,
#          'to obtain': 3,
#          'with each': 3,
#          'each other': 3,
#          'form of': 3,
#          ', in': 3,
#          'their O': 3,
#          ', when': 3,
#          'S for': 3,
#          'O over': 3,
#          '. S of': 3,
#          'with each other': 3,
#          'because S be': 3,
#          ', S of': 3,
#          'O and the': 3,
#          'S with': 3,
#          'in the war': 3,
#          'the seabirds': 3,
#          'than S had': 3,
#          'the Peruvian S': 3,
#          'O with': 3,
#          'merchants ,': 3,
#          'terms S': 3,
#          'of territory': 3,
#          ', a': 3,
#          'the 1870s': 3,
#          'at the': 2,
#          '. .': 2,
#          'My S': 2,
#          ', so': 2,
#          "n't be": 2,
#          'much .': 2,
#          'way to': 2,
#          "'ve been": 2,
#          'O , but': 2,
#          ". S 've": 2,
#          "S 've been": 2,
#          'O , and': 2,
#          ". S 've been": 2,
#          'office .': 2,
#          'the woman': 2,
#          "woman 's": 2,
#          'to work': 2,
#          'again .': 2,
#          'the airport': 2,
#          'airport .': 2,
#          'to the airport': 2,
#          'the airport .': 2,
#          'O to the airport': 2,
#          'to the airport .': 2,
#          'S guess': 2,
#          'guess S': 2,
#          'just have': 2,
#          'for a': 2,
#          'a bit': 2,
#          'until S': 2,
#          'S guess S': 2,
#          "guess S 'll": 2,
#          'just have to': 2,
#          "S guess S 'll": 2,
#          '. And': 2,
#          'And S': 2,
#          'get O .': 2,
#          'her O': 2,
#          'Hey ,': 2,
#          'to her': 2,
#          'S only': 2,
#          'a few': 2,
#          "n't just": 2,
#          'do O': 2,
#          '. Let': 2,
#          'Let S': 2,
#          'out O': 2,
#          'encourage O': 2,
#          'to step': 2,
#          'step down': 2,
#          'down .': 2,
#          "ca n't just": 2,
#          '. Let S': 2,
#          'O to step': 2,
#          'to step down': 2,
#          'step down .': 2,
#          "S ca n't just": 2,
#          'O to step down': 2,
#          'to step down .': 2,
#          'a new': 2,
#          'why S': 2,
#          'recently .': 2,
#          'be just': 2,
#          'just a': 2,
#          'to make': 2,
#          'the same': 2,
#          'same O': 2,
#          'S be just': 2,
#          'the same O': 2,
#          'same O .': 2,
#          'the same O .': 2,
#          'his TV': 2,
#          'for his': 2,
#          'O for his': 2,
#          'could not': 2,
#          'S could not': 2,
#          'If S': 2,
#          'regular stores': 2,
#          'stores .': 2,
#          'regular stores .': 2,
#          'are S': 2,
#          'S always': 2,
#          '! But': 2,
#          'of it': 2,
#          'O of it': 2,
#          'O at': 2,
#          'a good': 2,
#          'two O': 2,
#          'tell O': 2,
#          'more O': 2,
#          'to design': 2,
#          'S thought': 2,
#          'sculpture .': 2,
#          'psychology O': 2,
#          'take O': 2,
#          'today .': 2,
#          'be S': 2,
#          'S put': 2,
#          'O off': 2,
#          'the last': 2,
#          'S be S': 2,
#          'know ,': 2,
#          'know .': 2,
#          'S know ,': 2,
#          'S know .': 2,
#          'to Jim': 2,
#          "Jim 's": 2,
#          "'s party": 2,
#          'to go to': 2,
#          'go to Jim': 2,
#          "to Jim 's": 2,
#          "Jim 's party": 2,
#          "go to Jim 's": 2,
#          "to Jim 's party": 2,
#          'can not': 2,
#          'but S be': 2,
#          ', but S be': 2,
#          'let S know': 2,
#          'ask for': 2,
#          '. But': 2,
#          '. But S': 2,
#          'how to': 2,
#          'O O': 2,
#          'His S': 2,
#          'S need': 2,
#          'need to': 2,
#          'Hong Kong': 2,
#          'the Japanese': 2,
#          'could be': 2,
#          'S could be': 2,
#          ', S should': 2,
#          'have helped': 2,
#          'S avoid': 2,
#          'avoid high': 2,
#          'high O': 2,
#          'S have helped': 2,
#          'have helped S': 2,
#          'helped S avoid': 2,
#          'S avoid high': 2,
#          'avoid high O': 2,
#          'high O .': 2,
#          'S have helped S': 2,
#          'have helped S avoid': 2,
#          'helped S avoid high': 2,
#          'S avoid high O': 2,
#          'avoid high O .': 2,
#          'the highest': 2,
#          'may limit': 2,
#          'limit participants': 2,
#          "participants '": 2,
#          "' job": 2,
#          'job O': 2,
#          'S may limit': 2,
#          'may limit participants': 2,
#          "limit participants '": 2,
#          "participants ' job": 2,
#          "' job O": 2,
#          'job O .': 2,
#          'S may limit participants': 2,
#          "may limit participants '": 2,
#          "limit participants ' job": 2,
#          "participants ' job O": 2,
#          "' job O .": 2,
#          'make S': 2,
#          'school S': 2,
#          'be less': 2,
#          'less reliant': 2,
#          'reliant on': 2,
#          'on fossil': 2,
#          'fossil fuels': 2,
#          'fuels .': 2,
#          'S be less': 2,
#          'be less reliant': 2,
#          'less reliant on': 2,
#          'reliant on fossil': 2,
#          'on fossil fuels': 2,
#          'fossil fuels .': 2,
#          'S be less reliant': 2,
#          'be less reliant on': 2,
#          'less reliant on fossil': 2,
#          'reliant on fossil fuels': 2,
#          'on fossil fuels .': 2,
#          'harmful to': 2,
#          'harmful to the': 2,
#          'The methane': 2,
#          'methane S': 2,
#          'S produce': 2,
#          'produce O': 2,
#          'O recycling': 2,
#          'recycling O': 2,
#          'The methane S': 2,
#          'methane S produce': 2,
#          'S produce O': 2,
#          'produce O recycling': 2,
#          'O recycling O': 2,
#          'recycling O .': 2,
#          'The methane S produce': 2,
#          'methane S produce O': 2,
#          'S produce O recycling': 2,
#          'produce O recycling O': 2,
#          'O recycling O .': 2,
#          'to complete': 2,
#          'complete the': 2,
#          'the assigned': 2,
#          'assigned O': 2,
#          'would not be': 2,
#          'not be able': 2,
#          'able to complete': 2,
#          'to complete the': 2,
#          'complete the assigned': 2,
#          'the assigned O': 2,
#          'assigned O .': 2,
#          'S would not be': 2,
#          'would not be able': 2,
#          'not be able to': 2,
#          'be able to complete': 2,
#          'able to complete the': 2,
#          'to complete the assigned': 2,
#          'complete the assigned O': 2,
#          'the assigned O .': 2,
#          'the US': 2,
#          'US O': 2,
#          'the US O': 2,
#          'Ensuring that': 2,
#          'be safer': 2,
#          'safer to': 2,
#          'to operate': 2,
#          'operate .': 2,
#          'Ensuring that S': 2,
#          'that S would': 2,
#          'would be safer': 2,
#          'be safer to': 2,
#          'safer to operate': 2,
#          'to operate .': 2,
#          'Ensuring that S would': 2,
#          'that S would be': 2,
#          'S would be safer': 2,
#          'would be safer to': 2,
#          'be safer to operate': 2,
#          'safer to operate .': 2,
#          'new O': 2,
#          'be sometimes': 2,
#          'sometimes eaten': 2,
#          'eaten by': 2,
#          'S be sometimes': 2,
#          'be sometimes eaten': 2,
#          'sometimes eaten by': 2,
#          'eaten by the': 2,
#          'by the males': 2,
#          'S be sometimes eaten': 2,
#          'be sometimes eaten by': 2,
#          'sometimes eaten by the': 2,
#          'eaten by the males': 2,
#          'by the males .': 2,
#          'be larger': 2,
#          'larger than': 2,
#          'than the': 2,
#          'S be larger': 2,
#          'be larger than': 2,
#          'S be larger than': 2,
#          'By keeping': 2,
#          'keeping O': 2,
#          'from sinking': 2,
#          'sinking .': 2,
#          'By keeping O': 2,
#          'keeping O from': 2,
#          'O from sinking': 2,
#          'from sinking .': 2,
#          'By keeping O from': 2,
#          'keeping O from sinking': 2,
#          'O from sinking .': 2,
#          'been affected': 2,
#          'affected by': 2,
#          'by air': 2,
#          'air pollution': 2,
#          'pollution .': 2,
#          'Their S had': 2,
#          'had been affected': 2,
#          'been affected by': 2,
#          'affected by air': 2,
#          'by air pollution': 2,
#          'air pollution .': 2,
#          'Their S had been': 2,
#          'S had been affected': 2,
#          'had been affected by': 2,
#          'been affected by air': 2,
#          'affected by air pollution': 2,
#          'by air pollution .': 2,
#          'S affected': 2,
#          'affected a': 2,
#          'a wide': 2,
#          'wide O': 2,
#          'of people': 2,
#          'people in': 2,
#          'in ancient': 2,
#          'ancient Egypt': 2,
#          'Egypt .': 2,
#          'S affected a': 2,
#          'affected a wide': 2,
#          'a wide O': 2,
#          'wide O of': 2,
#          'O of people': 2,
#          'of people in': 2,
#          'people in ancient': 2,
#          'in ancient Egypt': 2,
#          'ancient Egypt .': 2,
#          'S affected a wide': 2,
#          'affected a wide O': 2,
#          'a wide O of': 2,
#          'wide O of people': 2,
#          'O of people in': 2,
#          'of people in ancient': 2,
#          'people in ancient Egypt': 2,
#          'in ancient Egypt .': 2,
#          'wealthy O': 2,
#          'be first': 2,
#          'S be first': 2,
#          'replication S': 2,
#          'out by': 2,
#          'by researchers': 2,
#          'the researchers': 2,
#          'carried out by': 2,
#          'S attempted': 2,
#          'of studies': 2,
#          'practice ,': 2,
#          'be actually': 2,
#          'such as': 2,
#          'fraud and': 2,
#          'journals .': 2,
#          'S be actually': 2,
#          'Since S': 2,
#          'of p': 2,
#          'hacking .': 2,
#          'of p -': 2,
#          '- hacking .': 2,
#          'of p - hacking': 2,
#          'p - hacking .': 2,
#          'Although S': 2,
#          'Although S be': 2,
#          'psychology .': 2,
#          'of psychology .': 2,
#          'field of psychology .': 2,
#          'likely to': 2,
#          "researchers '": 2,
#          '- known': 2,
#          'researchers to': 2,
#          'studies S': 2,
#          'the most': 2,
#          'of psychological': 2,
#          'psychological research': 2,
#          'claiming that': 2,
#          'follow -': 2,
#          "Nosek 's": 2,
#          "'s study": 2,
#          'of psychological research': 2,
#          "Nosek 's study": 2,
#          '" S be': 2,
#          'of Germany': 2,
#          "'s chancellor": 2,
#          'chancellor immediately': 2,
#          'immediately following': 2,
#          'following O': 2,
#          'the armistice': 2,
#          'armistice caused': 2,
#          'caused his': 2,
#          'his S': 2,
#          'the army': 2,
#          'army to': 2,
#          'to worsen': 2,
#          'worsen greatly': 2,
#          'greatly .': 2,
#          'S of Germany': 2,
#          "of Germany 's": 2,
#          "Germany 's chancellor": 2,
#          "'s chancellor immediately": 2,
#          'chancellor immediately following': 2,
#          'immediately following O': 2,
#          'following O of': 2,
#          'of the armistice': 2,
#          'the armistice caused': 2,
#          'armistice caused his': 2,
#          'caused his S': 2,
#          'his S with': 2,
#          'S with the': 2,
#          'with the army': 2,
#          'the army to': 2,
#          'army to worsen': 2,
#          'to worsen greatly': 2,
#          'worsen greatly .': 2,
#          "S of Germany 's": 2,
#          "of Germany 's chancellor": 2,
#          "Germany 's chancellor immediately": 2,
#          "'s chancellor immediately following": 2,
#          'chancellor immediately following O': 2,
#          'immediately following O of': 2,
#          'following O of the': 2,
#          'O of the armistice': 2,
#          'of the armistice caused': 2,
#          'the armistice caused his': 2,
#          'armistice caused his S': 2,
#          'caused his S with': 2,
#          'his S with the': 2,
#          'S with the army': 2,
#          'with the army to': 2,
#          'the army to worsen': 2,
#          'army to worsen greatly': 2,
#          'to worsen greatly .': 2,
#          'by German': 2,
#          'German commanders': 2,
#          'commanders in': 2,
#          "war 's": 2,
#          "'s early": 2,
#          'early days': 2,
#          'days weakened': 2,
#          'weakened the': 2,
#          "'s bargaining": 2,
#          'bargaining O': 2,
#          'O when': 2,
#          'Versailles was': 2,
#          'was proposed': 2,
#          'proposed .': 2,
#          'S made by': 2,
#          'made by German': 2,
#          'by German commanders': 2,
#          'German commanders in': 2,
#          'commanders in the': 2,
#          "the war 's": 2,
#          "war 's early": 2,
#          "'s early days": 2,
#          'early days weakened': 2,
#          'days weakened the': 2,
#          'weakened the country': 2,
#          "country 's bargaining": 2,
#          "'s bargaining O": 2,
#          'bargaining O when': 2,
#          'O when S': 2,
#          'when S of': 2,
#          'of Versailles was': 2,
#          'Versailles was proposed': 2,
#          'was proposed .': 2,
#          'S made by German': 2,
#          'made by German commanders': 2,
#          'by German commanders in': 2,
#          'German commanders in the': 2,
#          'commanders in the war': 2,
#          "in the war 's": 2,
#          "the war 's early": 2,
#          "war 's early days": 2,
#          "'s early days weakened": 2,
#          'early days weakened the': 2,
#          'days weakened the country': 2,
#          "weakened the country 's": 2,
#          "the country 's bargaining": 2,
#          "country 's bargaining O": 2,
#          "'s bargaining O when": 2,
#          'bargaining O when S': 2,
#          'O when S of': 2,
#          'when S of Versailles': 2,
#          'S of Versailles was': 2,
#          'of Versailles was proposed': 2,
#          'Versailles was proposed .': 2,
#          'enemy S': 2,
#          'been intended': 2,
#          'to influence': 2,
#          'influence German': 2,
#          'German O': 2,
#          'O instead': 2,
#          'instead caused': 2,
#          'turn against': 2,
#          'against the': 2,
#          "'s government": 2,
#          'government .': 2,
#          'enemy S S': 2,
#          'S S had': 2,
#          'had been intended': 2,
#          'been intended to': 2,
#          'intended to influence': 2,
#          'to influence German': 2,
#          'influence German O': 2,
#          'German O instead': 2,
#          'O instead caused': 2,
#          'instead caused S': 2,
#          'S to turn': 2,
#          'to turn against': 2,
#          'turn against the': 2,
#          'against the country': 2,
#          "country 's government": 2,
#          "'s government .": 2,
#          'enemy S S had': 2,
#          'S S had been': 2,
#          'S had been intended': 2,
#          'had been intended to': 2,
#          'been intended to influence': 2,
#          'intended to influence German': 2,
#          'to influence German O': 2,
#          'influence German O instead': 2,
#          'German O instead caused': 2,
#          'O instead caused S': 2,
#          'instead caused S to': 2,
#          'caused S to turn': 2,
#          'S to turn against': 2,
#          'to turn against the': 2,
#          'turn against the country': 2,
#          "against the country 's": 2,
#          "the country 's government": 2,
#          "country 's government .": 2,
#          'Despite many': 2,
#          'many people': 2,
#          'people thinking': 2,
#          'thinking S': 2,
#          'S did': 2,
#          'not mean': 2,
#          'mean S': 2,
#          'to pay': 2,
#          'pay for': 2,
#          'damage caused': 2,
#          'caused during': 2,
#          'during the': 2,
#          'had other': 2,
#          'other economic': 2,
#          'be even': 2,
#          'even more': 2,
#          'more serious': 2,
#          'serious .': 2,
#          'Despite many people': 2,
#          'many people thinking': 2,
#          'people thinking S': 2,
#          'thinking S did': 2,
#          'S did not': 2,
#          'did not mean': 2,
#          'not mean S': 2,
#          'mean S had': 2,
#          'had to pay': 2,
#          'to pay for': 2,
#          'pay for damage': 2,
#          'for damage caused': 2,
#          'damage caused during': 2,
#          'caused during the': 2,
#          'during the war': 2,
#          'war , S': 2,
#          'S had other': 2,
#          'had other economic': 2,
#          'other economic O': 2,
#          'economic O S': 2,
#          'S be even': 2,
#          'be even more': 2,
#          'even more serious': 2,
#          'more serious .': 2,
#          'Despite many people thinking': 2,
#          'many people thinking S': 2,
#          'people thinking S did': 2,
#          'thinking S did not': 2,
#          'S did not mean': 2,
#          'did not mean S': 2,
#          'not mean S had': 2,
#          'mean S had to': 2,
#          'S had to pay': 2,
#          'had to pay for': 2,
#          'to pay for damage': 2,
#          'pay for damage caused': 2,
#          'for damage caused during': 2,
#          'damage caused during the': 2,
#          'caused during the war': 2,
#          'during the war ,': 2,
#          'the war , S': 2,
#          'war , S had': 2,
#          ', S had other': 2,
#          'S had other economic': 2,
#          'had other economic O': 2,
#          'other economic O S': 2,
#          'economic O S be': 2,
#          'O S be even': 2,
#          'S be even more': 2,
#          'be even more serious': 2,
#          'even more serious .': 2,
#          'be seen': 2,
#          'seen as': 2,
#          'as severely': 2,
#          'severely punishing': 2,
#          'punishing O': 2,
#          'for starting': 2,
#          'starting O': 2,
#          'S mostly': 2,
#          'mostly gave': 2,
#          'gave a': 2,
#          'a legal': 2,
#          'legal O': 2,
#          'relatively favorable': 2,
#          'S be seen': 2,
#          'be seen as': 2,
#          'seen as severely': 2,
#          'as severely punishing': 2,
#          'severely punishing O': 2,
#          'punishing O for': 2,
#          'O for starting': 2,
#          'for starting O': 2,
#          'starting O ,': 2,
#          'S mostly gave': 2,
#          'mostly gave a': 2,
#          'gave a legal': 2,
#          'a legal O': 2,
#          'legal O for': 2,
#          'S be seen as': 2,
#          'be seen as severely': 2,
#          'seen as severely punishing': 2,
#          'as severely punishing O': 2,
#          'severely punishing O for': 2,
#          'punishing O for starting': 2,
#          'O for starting O': 2,
#          'for starting O ,': 2,
#          'S mostly gave a': 2,
#          'mostly gave a legal': 2,
#          'gave a legal O': 2,
#          'a legal O for': 2,
#          'Though S': 2,
#          'came to': 2,
#          'be blamed': 2,
#          'blamed for': 2,
#          "'s problems": 2,
#          'really the': 2,
#          'the Nazis': 2,
#          'Nazis themselves': 2,
#          'themselves S': 2,
#          'be causing': 2,
#          'causing O': 2,
#          'Though S came': 2,
#          'S came to': 2,
#          'came to be': 2,
#          'to be blamed': 2,
#          'be blamed for': 2,
#          'blamed for Germany': 2,
#          "Germany 's problems": 2,
#          "'s problems ,": 2,
#          'problems , S': 2,
#          'be really the': 2,
#          'really the Nazis': 2,
#          'the Nazis themselves': 2,
#          'Nazis themselves S': 2,
#          'themselves S be': 2,
#          'S be causing': 2,
#          'be causing O': 2,
#          'causing O .': 2,
#          'Though S came to': 2,
#          'S came to be': 2,
#          'came to be blamed': 2,
#          'to be blamed for': 2,
#          'be blamed for Germany': 2,
#          "blamed for Germany 's": 2,
#          "for Germany 's problems": 2,
#          "Germany 's problems ,": 2,
#          "'s problems , S": 2,
#          'problems , S be': 2,
#          ', S be really': 2,
#          'S be really the': 2,
#          'be really the Nazis': 2,
#          'really the Nazis themselves': 2,
#          'the Nazis themselves S': 2,
#          'Nazis themselves S be': 2,
#          'themselves S be causing': 2,
#          'S be causing O': 2,
#          'be causing O .': 2,
#          'the area': 2,
#          'area of': 2,
#          'islands carried': 2,
#          'carried large': 2,
#          'large O': 2,
#          'of nitrates': 2,
#          'nitrates to': 2,
#          'guano mounds': 2,
#          'mounds ,': 2,
#          ', making': 2,
#          'making S': 2,
#          'S resistant': 2,
#          'resistant to': 2,
#          'the effects': 2,
#          'effects of': 2,
#          "islands '": 2,
#          "' arid": 2,
#          'arid air': 2,
#          'S S in': 2,
#          'in the area': 2,
#          'the area of': 2,
#          'area of the': 2,
#          'the islands carried': 2,
#          'islands carried large': 2,
#          'carried large O': 2,
#          'large O of': 2,
#          'O of nitrates': 2,
#          'of nitrates to': 2,
#          'nitrates to the': 2,
#          ...})

# %%
wordlist_by_grade: dict[str, list[str]] = {}

for path in tqdm(glob.glob('../../data/wordlist-sources/*.json')):
    with open(path, 'r') as f:
        data: list[str] = json.load(f)
    grade = pathlib.Path(path).stem.split('_')[0]
    wordlist_by_grade.setdefault(grade, []).extend(data)
wordlist_by_grade
# Out:
# 100%|██████████| 105/105 [00:00<00:00, 23144.94it/s]
# {'1': ['What are the two people talking about?',
#   "Julie's poor work performance.",
#   'A project Rachel is working on.',
#   'Personal criticisms being shared accidentally.',
#   "Problems with the office's online forum.",
#   'What is one thing we learn about the play?',
#   'Some casting decisions have led to disagreements.',
#   "It is the director's first production.",
#   'The technical staff is having serious problems.',
#   'The opening day will probably be delayed.',
#   'What does the man say the woman should have done?',
#   'Rearranged her work schedule.',
#   'Checked the budget figures herself.',
#   'Reported the reason for the delay.',
#   'Taken the blame for the delay.',
#   'What do we learn from the conversation?',
#   'Oceans have become a source of new medicines.',
#   'Testing medicines on marine animals is becoming common.',
#   'New medicines are likely to help with space exploration.',
#   'The approval process for a new medicine has been shortened.',
#   'What does the man think about his daughter?',
#   'She is making the decision too quickly.',
#   'She should go to the smaller university.',
#   'She should try to extend her study in Spain.',
#   'She might not feel comfortable in a big city.',
#   'What does the consultant suggest?',
#   'Start firing low-performing employees.',
#   'Reconsider how the company sets deadlines.',
#   'Allow employees to propose their own sales targets.',
#   'Begin to reward staff for good performances.',
#   'What is the complication with the sale?',
#   'The house failed an inspection.',
#   'The work on the attic is not complete.',
#   'The buyer wants the couple to lower the price.',
#   'The buyer has a poor credit rating.',
#   'According to the 2016 study, what may affect the way government leaders smile in photos?',
#   'The mood they are in before the photos are taken.',
#   'The value their cultures put on certain emotions.',
#   'The overall level of happiness in their country.',
#   'The types of questions citizens ask them.',
#   "According to Paula Niedenthal's research, why might smiling be more common in some countries?",
#   'Their cultures have changed little over time.',
#   'It is a way to protect their culture from outside influence.',
#   'It helps people communicate without relying on language.',
#   'They experienced limited immigration.',
#   'What is one use of octenol by mosquitos?',
#   'Mosquitos often mistake it for lactic acid.',
#   'Its odor is used by mosquitos to find victims.',
#   'It can deter mosquitos when combined with ammonia.',
#   'Mosquitos can use it as a source of energy.',
#   'According to the passage, what is one reason exercise can help reduce mosquito bites?',
#   'Exercise blocks the production of certain chemicals.',
#   'Body heat declines after training.',
#   'Athletes tend to consume less alcohol.',
#   'Metabolic rates increase with physical activity.',
#   'Why are flowers sometimes thrown at men joining the army?',
#   'To shame them for not joining the army.',
#   'To show appreciation for their speeches.',
#   'To discourage them from becoming soldiers.',
#   'To make their uniforms more attractive.',
#   'Which men used to get extra decorations on their uniforms?',
#   'Men whose uniforms had not yet arrived.',
#   'Men who were working as army doctors.',
#   'Men who had left the military for health reasons.',
#   'Men who were in important government positions.',
#   'What is one reason that companies with unclear rules may lose more staff?',
#   'They rarely set clear regulations.',
#   'Employees may feel less personal responsibility.',
#   'Employees get tired due to the lack of breaks.',
#   'They are to blame for many employees quitting.',
#   'According to the passage, what is one benefit of using wearable monitors in the workplace?',
#   "The data gathered can be used to help improve employees' lives.",
#   'Employees can be responsible for inputting their own data.',
#   'They can be used to determine employee bonuses.',
#   'Teams can be monitored instead of individuals.',
#   'What is one thing scientists have learned about mass extinctions?',
#   'When a particular mass extinction event occurred.',
#   'Which large animals are more likely to survive mass extinctions.',
#   'What various animals ate before and after a mass extinction.',
#   'What role climate played in the extinction of certain mammals.',
#   'According to the passage, what is one important role played by large herbivores after mass extinction events?',
#   'Meateating mammals are particularly prone to extinction.',
#   'Conservation efforts have become more effective recently.',
#   'Sabertoothed cats hunted less than previously believed.',
#   'Large herbivores play an important role in ecosystems.',
#   'Situation: You are a director at a company. You will leave town for a business trip next Wednesday. In a private meeting, the CEO tells you the following.Make sure that no information about the merger leaks out before the official announcement. Ask department heads not to discuss it and prepare a statement for the staff intranet, but only post it after the press release. There have been problems with leaks in the past, so we have to be careful.',
#   'Prepare a merger statement to show the CEO.',
#   'Post information to staff on the intranet.',
#   'Speak with department heads about the merger.',
#   'Make a plan to prevent leaks.',
#   "Situation: Your daughter's wedding reception is in three months. You plan to have a large flower arrangement on each guest table. You call a catering company and are told the following.Our Family Plan is perfect for events with a slightly casual atmosphere. All the food is served at once, family style, which does mean there won't be any space for elaborate decorations or settings on the tables. Of course, you can't go wrong with traditional plate service, and our Elegant Plan never fails to impress. With this option, guests choose their main dish, and you'll have more control over the menu. Please note this plan requires four months' notice. Next is our Country Plan, which provides a buffet-style meal. This plan is our most expensive, as more food is prepared, but a beautifully arranged buffet adds a striking visual touch to any reception and leaves plenty of room on each table. Finally, with our Star Plan, guests serve themselveswith some helpat various food stations. Guests love the interactive setup, but there's currently a five-month-long waiting list for the appliance rentals the stations require.",
#   'The Family Plan.',
#   'The Elegant Plan.',
#   'The Country Plan.',
#   'The Star Plan.',
#   "Situation: You recently joined a company as a department manager. You need a team leader with excellent software knowledge and good communication skills for a new project. Your assistant tells you the following.Let me tell you about some of the staff members that you could consider for the software project leader position. Glen would've been ideal since he managed the previous project, and everybody likes him. He's just been assigned to another project, though. Keiko just joined us last month, but she led several similar projects at her last job. And I think she's even more outgoing and approachable than Glen. Then, there's Jamie. She sometimes struggles a bit due to a lack of familiarity with our systems. That being said, she's got fantastic people skills and was a good team player in the last project. If Terence were a bit less introverted, he'd be excellent because he knows everything there is to know about coding. He should definitely be on the team, but it's probably better if he's in a subordinate role.",
#   'Glen.',
#   'Keiko.',
#   'Jamie.',
#   'Terence.',
#   "Situation: The roof of your home has been leaking water. You had new roof tiles put in 15 years ago. A roofing repair person inspects your home and tells you the following.You did the right thing by calling us. Some people patch leaks up themselves with roofing tape and forget about them, but they're almost guaranteed to lead to bigger problems down the line. Now, there are a few different locations where water is getting insome tiles seem to have been severely damaged by the recent hailstorms. Unless the tiles are over 25 years old, an entire roof replacement isn't necessary now, as there isn't any large-scale structural damage. Repairing the damaged tiles should be sufficient. This is urgent, though, as the water could damage the electrical wiring and create a safety hazard. Unfortunately, I also noticed some water damage on your first-floor hallway ceiling. This could be coming all the way from the leaky roof, but it's more likely to be a plumbing issue involving the bathroom directly above. I suggest calling a plumber if it doesn't resolve itself after I repair the roof.",
#   'Arrange to have the roof replaced.',
#   'Have the damaged tiles fixed.',
#   'Get someone to repair the electrical wiring.',
#   'Contact a plumber.',
#   "Situation: You have an important meeting at a client's office in 30 minutes. You are in a taxi. There are no train stations near the client's office. The driver tells you the following.The traffic report just said a car broke down about a mile ahead and is blocking a lane. Normally, I'd say we should just wait it out where we are, as the local highway patrol officers are pretty quick to fix these kinds of situations. But, with the recent rain and flooding on some of the surrounding roads, it might take a half hour or so to clear the road. I could make a U-turn at the next light and go back the opposite way on Route 1 to get to the expressway; that would get you where you're going pretty quickly, but I'd have to charge you for the toll. Alternatively, I can make a right just up ahead, on Brady Street, and take you straight down to the train station, if you think getting on a train might be quicker.",
#   'Stay on Route 1.',
#   'Wait for the highway patrol to arrive.',
#   'Make a U-turn.',
#   'Turn right on Brady Street.',
#   'this apparent contradiction',
#   'the cause of the missing hydrogen',
#   'the lack of evidence',
#   "Earth's low temperatures",
#   'are still not entirely understood',
#   'likely occurred much later',
#   'were too small to be significant',
#   'would have had the opposite effect',
#   'life on Earth was not inevitable',
#   'scientists can easily make mistakes',
#   'life may have evolved much earlier',
#   'not all stars evolve in the same way',
#   'this was only partially correct',
#   'only authors had the right to analyze texts',
#   "the author's intention had no relevance",
#   "readers' interpretations held little weight",
#   'not comparable to each other',
#   'often impossible to interpret',
#   'not created by single individuals',
#   'usually failed efforts by their authors',
#   'called into question',
#   'made slight changes to',
#   'increased the clarity of',
#   'tried to add context to',
#   "The nuclear fusion process of stars like the sun converts hydrogen atoms into helium, increasing the density of a star's core. This, in turn, heightens its pressure and raises its temperature. Astrophysicists believe the sun was approximately 30 percent dimmer during the solar system's early history, when the core was less dense, which would have had significant consequences for the planets. In fact, the relatively low amount of energy emitted by the sun during this time should, theoretically, have led to the expansion of Earth's polar ice caps, causing glaciers to engulf the entire planet. While this hypothesis appears logically sound, geologic records indicate that liquid water was present during this period, and that it was followed by the emergence of organic matter shortly after. Various theories have been proposed to address__. One commonly proposed theory is that the greenhouse effect, a process in which certain gases trap heat in the atmosphere, negated the effects of the dimmer sun. These gases could have been released through volcanic activity, or, according to a new idea, as a result of giant asteroids bombarding Earth in its early history. The catastrophic damage from these impacts would have melted enormous volumes of rock, causing vast lava lakes to form, which would have then released greenhouse gases such as carbon dioxide. Some scientists, however, suggest that such events__. Large volumes of certain greenhouse gases could have formed a dense haze layer in Earth's atmosphere. This would likely have reflected sunlight while allowing thermal energy to escape, resulting in a more frigid climate. Clearly, if the as yet unknown cause of Earth's warming had not existed, the planet could very well have remained icy and barren. Conversely, if the young sun had released nearly as much energy as it does today, Earth may have been too scorching to allow for the presence of liquid water and, consequently, the beginning of life. In fact, computer simulations have indicated that our planet's habitability over billions of years has been contingent on numerous highly variable factors. The problem of the faint young sun reminds us, therefore, that__.",
#   'Roland Barthes and "The Death of the Author" Published in 1967, Roland Barthes\'s essay "The Death of the Author" was an assault on traditional literary criticism, which had held that a work of literature reflected the vision of its author. Proponents of this view emphasized, among other things, that examination of the author\'s biographical details was necessary to understand a text. Barthes, however, contended that__. Even literary works written anonymously, he argued, possess meaning regardless of whether the author\'s identity is known. According to Barthes, a text\'s meaning is a product of the language in which it is written as well as the associations made by its readers, not just the ideas the author intended to convey. Thus, for Barthes critics who attempt to explain works based on the supposed intentions of their authors do little more than repeat what he describes as "tyrannical" literary traditions. Barthes\'s essay has been criticized as an overreaction to the dominance of author-focused criticism in his time. While few now go as far as Barthes in rejecting the author as a relevant source of meaning, his ideas have encouraged a more balanced approach that considers both the intentions of authors and the contributions of readers to the creation of meaning.',
#   "Germany's use of defenses such as barbed wire and trenches was the main reason British tanks were not able to advance far into occupied enemy territory.",
#   'Although Britain had planned to use a large number of tanks in its attack, only a few of the vehicles were ready to be operated at the time of the battle.',
#   'The early tanks used by the British were not technologically advanced enough to be effective against the superior German forces.',
#   'Its military leaders tended to be distrustful of technologies that had not been sufficiently tested and proven successful on the battlefield.',
#   "The tank's failures at Cambrai made its military leaders skeptical that it could be used to effectively support either infantry or cavalry.",
#   'The leadership of the cavalry protested against plans to integrate tanks into the infantry as a way to support its soldiers in wars.',
#   'Its generals were unable to learn from the mistakes the British generals made with tanks at Cambrai.',
#   'Officers in its military came up with an original way of using tanks that was not restricted by limited resources in the same way as the British had been.',
#   'The fact that disputes among its leaders slowed progress within the nation makes it similar to modern computer companies.',
#   'At the height of the First World War, British forces launched a massive assault against German defensive positions in Cambrai, France, using a devastating new weapon: the tank. These armored vehicles were practically immune to the machine-gun fire that frequently mowed down waves of troops, and they could penetrate the barbed wire and lines of trenches the Germans had thought impregnable. Britain utilized hundreds of tanks in the assault, which led to an unprecedented advance of six miles and briefly appeared to have broken the long-existing stalemate between the opposing armies. With so many tanks involved in the assault, however, little was left in the way of reserves; a fact painfully realized after tanks on the front line broke down and needed maintenance or replacing. The difficulty in replenishing infantry and exhausted crewmen due to poor weather only made things worse, and with a majority of tanks out of commission, the attack stalled, allowing the Germans to retake territory.',
#   "Despite the British military's shortcomings later in the battle, the assault demonstrated its early lead in tank warfare. Britain frittered away this advancement, however, as it failed to incorporate the vehicles effectively into its military in the following decades. Armies in those days consisted of naval, infantry, and cavalry forces, and they were generally eager to embrace military innovations, as evidenced by the adoption of cutting-edge artillery and machine guns earlier during the First World War. These, however, were easily categorized as weapons for use by foot soldiers or in their support. The tank, on the other hand, presented a conundrum; when employed at Cambrai, it was made deliberately slow-moving so that infantry soldiers could keep pace with it, and tactics were developed so the two could support each other. The tank's primary characteristic, however, was mobility, which suggested it might fit in better with the cavalry's horseback-mounted troops. Yet the upper ranks of the cavalry were so enamored of their horses and the battle tactics specific to them that they balked at the integration of tanks.",
#   "Parallels have been drawn between the British army after the First World War and IBM, the former computer industry leader. IBM was well-known for successfully innovating room-sized mainframe computers sold to large institutions. When the personal computer was invented, however, the company stumbled because its organizational structure was unsuited to producing goods for ordinary consumers. Britain's military was similarly shackled by the structure of its institutional organization, which had no existing avenue for incorporating tank warfare. In contrast, the German military was almost entirely dismantled following its defeat in the First World War. It was not, therefore, encumbered by long-held institutions, entrenched hierarchies, or internal bickering, and when Adolf Hitler began rearming Germany in the 1930s, his generals saw enormous potential in tank warfare. In fact, they adopted tactics developed by the British officer behind the attack at Cambrai. The tank's mobility and firepower became a key facet of the German strategy of blitzkrieg, or lightning warfare, which enabled the Nazis to overrun most of Western Europe within weeks after the Second World War broke out.",
#   'He decided to go back to university to study.',
#   'He did not think the project was valuable.',
#   'He wanted a job that required less travel.',
#   'He did not have the right temperament for it.',
#   'Many of them will likely vanish unless people change their habits.',
#   'The expansion of urban areas will become the biggest threat to them.',
#   'Improved methods of pest control are positively impacting their conservation.',
#   'Measures to deal with long periods of drought are helping them to recover.',
#   "In the past, the main threat was deforestation to make way for urban areas, but today it's the climate change caused by global warming. To give just one example, warmer winters have led to an explosion in bark beetle populations in some areas. The beetles kill trees by feeding on them, and infestations can devastate forests. The cold winters used to kill off the beetles, but that isn't happening anymore, and the problem is exacerbated by extended periods of drought, which weaken trees, making them more vulnerable to attacks by pests. But I think the average person isn't really aware of the issue. I mean, I don't think they make the connection between their lifestyle choices and detrimental effects on forests. If we don't make a concerted effort to reduce our carbon footprint, I'm pessimistic about how many forests will be left for future generations.",
#   "The United States was concerned about the Soviet Union's progress because there was more at stake than simply the status that came from space exploration.",
#   'The Soviet Union realized more quickly than the United States that space exploration could greatly increase its national prestige.',
#   'Both countries believed that space technology would not be a significant factor in helping them gain military superiority over the other.',
#   'Both countries wanted to find a way to compete with the other in an area where there was no risk of nuclear war breaking out.',
#   "There was a general belief among government officials that the United States was not serious about going to the moon, despite John F. Kennedy's announcement.",
#   "Disagreements among various groups in the government and military led to a delay in the Soviet Union's decision to try to reach the moon.",
#   "The failure of a test mission in the United States' program to send astronauts to the moon gave the Soviet Union a false sense of victory in the Space Race.",
#   'Although the military received the largest share of funds meant for space exploration, much of this money was eventually redirected to the moon mission.',
#   "although the US and the Soviet space programs represented the countries' different political systems, they were actually very similar in many important ways.",
#   'although Sergei Korolev and Valentin Glushko thought their efforts would help to win the Cold War, the actions they took actually harmed their nation.',
#   'although the rocket the Soviets designed to take astronauts to the moon was thought to be a failure, it strongly influenced the planning of the successful US mission.',
#   'although the Soviet Union was a Communist state, its space program was run in a way that was more typical of a capitalist country like the United States.',
#   'this apparent contradiction',
#   'the cause of the missing hydrogen',
#   'the lack of evidence',
#   "Earth's low temperatures",
#   'are still not entirely understood',
#   'likely occurred much later',
#   'were too small to be significant',
#   'would have had the opposite effect',
#   'life on Earth was not inevitable',
#   'scientists can easily make mistakes',
#   'life may have evolved much earlier',
#   'not all stars evolve in the same way',
#   "Germany's use of defenses such as barbed wire and trenches was the main reason British tanks were not able to advance far into occupied enemy territory.",
#   'Although Britain had planned to use a large number of tanks in its attack, only a few of the vehicles were ready to be operated at the time of the battle.',
#   'The early tanks used by the British were not technologically advanced enough to be effective against the superior German forces.',
#   'Although tanks were initially used to gain an edge over the Germans, the British were unable to see this through to a decisive victory.',
#   'Its military leaders tended to be distrustful of technologies that had not been sufficiently tested and proven successful on the battlefield.',
#   "The tank's slow speed made it unsuited for the types of tactics where cavalry would have excelled, leading to institutional resistance from cavalry officers.",
#   'The British government lacked the necessary funds to support the integration of new military technologies such as tanks.',
#   'Many believed the tank would soon become obsolete due to advances in weaponry, making it a poor investment for the future.',
#   "Although the United States had developed nuclear weapons a few years ahead of the Soviets, it was the latter who had taken an early interest in pursuing missile technology to deliver such weapons. Since the similarity between missiles and space rockets meant that improvements in the latter would benefit the development of the former, the Soviets' initial lead in the Space Race represented an existential threat to the Americans. Although the Soviets had launched the first manned space mission in 1961, a combination of factors resulted in their lead being squandered. First, there was a tremendous clash of objectives between the military, which provided funding for space exploration, and rival factions within the government. After US president John F. Kennedy announced in 1961 that the United States would reach the moon before the decade ended, bureaucratic infighting within the Soviet Union led to the nation's financial resources being allocated to a wider range of projects. Many of these were purely military rather than exploratory, resulting in fewer available funds for a moon mission. Furthermore, despite the Soviet Union's determination to outperform the United States, its leader, Nikita Khrushchev, did not order a moon mission until 1964, months after the United States had tested the module that would carry its astronauts to the moon. Another major cause of the Soviet Union's failure is an ironic one. The Space Race was part of the Cold War, a decades-long rivalry between the capitalist, democratic United States and the Communist Soviet Union. Early on, however, the United States formed NASA to provide a top-down organization answerable to the federal governmenta model that would not be out of place in a Communist state. In contrast, the competing jumble of organizations and factions involved in the Soviet space program corresponded more closely to what one would anticipate in a capitalist system. For example, two prominent rocket engineers, Sergei Korolev and Valentin Glushko, came into conflict over what type of fuel to use, and an official commission ruled in favor of Korolev's proposal. Glushko, however, used his connections in government to organize a parallel project that diverted already scarce resources away from Korolev's plan. Eventually, the organizational problems and policy failures of the Soviet space program culminated in the rocket it intended to use to take astronauts to the moon experiencing disastrous technical failures, allowing the United States to complete its own moon mission.",
#   "The nuclear fusion process of stars like the sun converts hydrogen atoms into helium, increasing the density of a star's core. This, in turn, heightens its pressure and raises its temperature. Astrophysicists believe the sun was approximately 30 percent dimmer during the solar system's early history, when the core was less dense, which would have had significant consequences for the planets. In fact, the relatively low amount of energy emitted by the sun during this time should, theoretically, have led to the expansion of Earth's polar ice caps, causing glaciers to engulf the entire planet. While this hypothesis appears logically sound, geologic records indicate that liquid water was present during this period, and that it was followed by the emergence of organic matter shortly after. Various theories have been proposed to address ( 26 ). One commonly proposed theory is that the greenhouse effect, a process in which certain gases trap heat in the atmosphere, negated the effects of the dimmer sun. These gases could have been released through volcanic activity, or, according to a new idea, as a result of giant asteroids bombarding Earth in its early history. The catastrophic damage from these impacts would have melted enormous volumes of rock, causing vast lava lakes to form, which would have then released greenhouse gases such as carbon dioxide. Some scientists, however, suggest that such events ( 27 ). Large volumes of certain greenhouse gases could have formed a dense haze layer in Earth's atmosphere. This would likely have reflected sunlight while allowing thermal energy to escape, resulting in a more frigid climate. Clearly, if the as yet unknown cause of Earth's warming had not existed, the planet could very well have remained icy and barren. Conversely, if the young sun had released nearly as much energy as it does today, Earth may have been too scorching to allow for the presence of liquid water and, consequently, the beginning of life. In fact, computer simulations have indicated that our planet's habitability over billions of years has been contingent on numerous highly variable factors. The problem of the faint young sun reminds us, therefore, that ( 28 ).",
#   "Despite the British military's shortcomings later in the battle, the assault demonstrated its early lead in tank warfare. Britain frittered away this advancement, however, as it failed to incorporate the vehicles effectively into its military in the following decades. Armies in those days consisted of naval, infantry, and cavalry forces, and they were generally eager to embrace military innovations, as evidenced by the adoption of cutting-edge artillery and machine guns earlier during the First World War. These, however, were easily categorized as weapons for use by foot soldiers or in their support. The tank, on the other hand, presented a conundrum; when employed at Cambrai, it was made deliberately slow-moving so that infantry soldiers could keep pace with it, and tactics were developed so the two could support each other. The tank's primary characteristic, however, was mobility, which suggested it might fit in better with the cavalry's horseback-mounted troops. Yet the upper ranks of the cavalry were so enamored of their horses and the battle tactics specific to them that they balked at the integration of tanks. Parallels have been drawn between the British army after the First World War and IBM, the former computer industry leader. IBM was well-known for successfully innovating room-sized mainframe computers sold to large institutions. When the personal computer was invented, however, the company stumbled because its organizational structure was unsuited to producing goods for ordinary consumers. Britain's military was similarly shackled by the structure of its institutional organization, which had no existing avenue for incorporating tank warfare. In contrast, the German military was almost entirely dismantled following its defeat in the First World War. It was not, therefore, encumbered by long-held institutions, entrenched hierarchies, or internal bickering, and when Adolf Hitler began rearming Germany in the 1930s, his generals saw enormous potential in tank warfare. In fact, they adopted tactics developed by the British officer behind the attack at Cambrai. The tank's mobility and firepower became a key facet of the German strategy of blitzkrieg, or lightning warfare, which enabled the Nazis to overrun most of Western Europe within weeks after the Second World War broke out.",
#   'Thanks for showing me the apartment.',
#   "If you've decided on it, we can do the paperwork today.",
#   "The location's ideal, and the layout is great. But it's just a bit beyond my budget.",
#   "You'll be hard-pressed to find anything cheaper in this location.",
#   "If you'd consider reducing the rent by $50, I'd commit right away.",
#   "Well, I'll have to confirm it with the owner, but I don't see that being a problem. Let's head to the office.",
#   'The apartment may no longer be available.',
#   'There are other apartments in better locations.',
#   'The owner wants to raise the rent.',
#   'Did you watch the election debate last night?',
#   "Yes. It was helpful. I thought that many of Fatima Clark's ideas were exactly what this state needs right now.",
#   "Well, I'm glad you found it enlightening. I'm still finding it hard to differentiate between the candidates.",
#   "I guess they are similar in terms of economic policies, but I thought that Clark's environmental and education policies stood out.",
#   "I think I'll check out her campaign literature to find out more about her.",
#   "He wants to get involved with Fatima Clark's campaign.",
#   'He is most concerned about economic issues.',
#   'He is looking forward to watching the next debate.',
#   'What did you think of the film?',
#   "Well, I had big expectations for it because of the novel it's based on, but right now I'm feeling pretty let down.",
#   "It's been ages since I read the book, so it's not fresh in my mind.",
#   "Well, they eliminated several crucial characters. And condensing the plot so much was a huge mistake. It really should have been a TV series. That way, it could have been more faithful to the author's intentions.",
#   'The plot was too complicated.',
#   'It did not feel realistic.',
#   'The characters were not interesting.',
#   'I hear you want to buy a house. Are you looking at any areas in particular?',
#   'Well, our realtor says schools on the east side of town are better.',
#   "Frankly, they aren't any better than the ones on the west side. That image is just a reflection of people's stereotypes.",
#   'What do you mean?',
#   'Well, the schools on the east side may have newer buildings and fancier computer labs, but the teachers and curriculums are consistently good throughout the whole district.',
#   "That's good to know.",
#   'They have gotten worse recently.',
#   'The east-side schools are better.',
#   'There is an overall lack of computer labs.',
#   "I've been thinking about our vacation plan. We can't afford it if we want to remodel the kitchen.",
#   'So, we can either relax and make some great memories, or we can finally upgrade our ancient kitchen.',
#   'Or do both but economize on each.',
#   "You mean by traveling closer to home and only replacing some of the appliances? I don't think we'd be happy with that.",
#   "True. Personally, I don't think I can put up with this kitchen for another year.",
#   'Me, neither. I guess that settles it.',
#   'Replace just some of their appliances.',
#   'Take a less expensive trip.',
#   'Give up on their vacation plan.',
#   "I was talking to Bill last night. He's amazingly well-read. He was telling me all about ancient Greek philosophy.",
#   "Yes, he certainly loves going on about literature and philosophy. But I'd take what he says with a pinch of salt.",
#   'What do you mean?',
#   "Well, I don't know if he's quite as knowledgeable as he claims to be. The other day, he got two completely different works by Shakespeare mixed up.",
#   'Really? But he always sounds so convincing.',
#   'He knows more about literature than philosophy.',
#   'He is boring when he discusses ancient Greece.',
#   'He received a high level of education.',
#   "I'd like to return these two rolls of wallpaper.",
#   'Was there a problem with them?',
#   'No. I just bought more than I needed.',
#   'OK. This paper was a special order, though, so I have to deduct a 25 percent restocking fee from your refund.',
#   "A restocking fee? What's that?",
#   "If returned items are special orders, a restocking fee covers the seller's handling costs. You'd have to pay the fee or keep the paper.",
#   "In that case, I'll keep it.",
#   'Ship the wallpaper back to the seller herself.',
#   'Refuse to pay the additional fee.',
#   'Keep the wallpaper rather than return it.',
#   "I hear you're a farmer. What inspired you to start your own farm?",
#   "Well, I grew up in the city, but always loved visiting my grandparents' farm as a child. I'd help with various chores, learned about crops and livestock, and discovered the satisfaction of raising food. As I got older, I studied agriculture, saved money, and eventually made the leap.",
#   "That's impressive. Why do you think so many people are interested in what you do?",
#   "There's a growing interest in sustainable food and a desire to understand where our food comes from. People want transparency and a connection to the land.",
#   'Do you also offer workshops?',
#   "Yes, I do. I love teaching others about farming's realities and rewards. I get a lot of visitors, from urbanites to aspiring farmers. Some want to buy my products, others want to experience life on a farm.",
#   'He wants to invest in her farm.',
#   'He wants to buy products from her farm.',
#   'He wants to sell her some farm equipment.',
#   'I think we need to attract more students to our tutoring service. My idea is to hire some specialized tutors and focus on specific school subjects.',
#   'That might help, but have you considered the risks? Posting ads on social media could expose tutors and students to privacy issues or scams.',
#   "That's a good point. Maybe we need to take some safety measures before starting a new campaign.",
#   'The feedback they received was not useful.',
#   'Having specialized tutors will make it easier.',
#   'Posting ads on social media involves risks.',
#   'Our client wants the new app to be delivered next week, but the requested features involve a lot of coding, and our team is already stretched thin.',
#   'That sounds tough. Is there any chance the client would be happy if you just demo the basic features first?',
#   "Maybe, but I'm worried showing an incomplete product will disappoint the client even more.",
#   "That's possible. I guess you'll have to weigh the risks and decide what's best for the situation.",
#   'The client might be discouraged by a live demo.',
#   "It is no longer one of the client's main priorities.",
#   "It should reflect recent changes in the client's values.",
#   '(A) No. 11 What is true about German radar during World War II?',
#   'Germany had stolen British radar equipment.',
#   'Germany had created its own radar system.',
#   'German radar bases had been built in Norway.',
#   'German planes could evade British radar.',
#   'No. 12 What did the man do with the report?',
#   'He predicted a large bombing raid.',
#   'He used the report to design new weapons.',
#   'He got the British to believe the report was true.',
#   'He traveled to Germany to get information.',
#   '(B) No. 13 What does the woman say about stromatolites?',
#   'They benefited from conditions caused by an extinction event.',
#   'Their survival was dependent on reef systems.',
#   'Their populations disappeared rapidly at one point.',
#   'They have existed longer than scientists once believed.',
#   'No. 14 What is a result of the new extinction model?',
#   'It leads some people to underestimate extinction rates.',
#   'It is the basis for the sixth mass extinction theory.',
#   'It places too much emphasis on marine life.',
#   'It encourages scientists to help conserve plant species.',
#   '(C) No. 15 What is true about the society described?',
#   'Its land allowed for easy farming.',
#   'Its people were not skilled farmers.',
#   'Its downfall was caused by poor harvests.',
#   'Its success was largely due to its agriculture.',
#   'No. 16 What was the main aim of the project?',
#   'Raise money to carry out archaeological research.',
#   'Provide financial help to struggling farmers.',
#   'Improve agriculture using traditional techniques.',
#   'Introduce farming methods brought from Spain.',
#   '(D) No. 17 What is true about the ancient marshes?',
#   'Most of them suffered from human overpopulation.',
#   'Many areas survived despite various external pressures.',
#   'Agricultural development of them was banned.',
#   'They provided drinking water for nearby cities.',
#   'No. 18 What is said about the marsh restoration project?',
#   'The marshes are facing threats to their existence again.',
#   'Local people must be prevented from overfishing the marshes.',
#   'World Heritage status should have been awarded earlier.',
#   "The government's restoration plan was not ambitious enough.",
#   '(E) No. 19 What is said about the painting?',
#   'It is not on public display.',
#   'Some of its details have been altered.',
#   'It was damaged during conservation work.',
#   'It was moved to a different gallery.',
#   'No. 20 What is true about art during the period described?',
#   'There was less demand for art.',
#   "Artists often copied each other's work.",
#   'Many paintings were banned because of their content.',
#   'It was common for paintings to be changed.',
#   'He began to see that cooperating with it on a temporary basis could be the key to achieving a united German nation.',
#   'He realized that for the German Confederation to succeed, Austria would need to become a member.',
#   'He formed the opinion that Prussia needed to be less aggressive toward Austria in order to preserve peace.',
#   "Bismarck intentionally angered other members of the German Confederation due to the demands of Prussia's monarch.",
#   'Against the wishes of other European nations, he helped to improve the position of Austria within the North German Confederation.',
#   'He deceived other German states about what their role in the new North German Confederation would be.',
#   'convincing them that the treaties they had signed with Prussia were not sufficient to protect them if they were attacked by France.',
#   'demonstrating that his country had such a powerful military that they had nothing to fear if they aligned themselves with Prussia.',
#   "making them believe that Prussia's treaty with France was actually highly unfavorable to their interests.",
#   'reflects the commonly held idea at the time that the peace between Germany and France would be a long-lasting one.',
#   'is evidence that Bismarck actually had the best interests of the southern German states in mind when he unified Germany.',
#   "shows that Bismarck failed to understand how much holding the ceremony there would affect Germany's future relations with France.",
#   "In the aftermath of the dramatic collapse of the Holy Roman Empire during the Napoleonic Wars of the early nineteenth century, the political landscape of Central Europe underwent a profound transformation. The territories that had composed the once-mighty empire eventually evolved into a diverse coalition of thirty-nine German-speaking kingdoms, free cities, and other states known collectively as the German Confederation. Although there was significant interest in the concept of forming a German nation, fragmentation and discord within this new alliance meant that achieving a cohesive state remained elusive for many decades. In the 1860s, however, the shrewd statesman Otto von Bismarck became the prime minister of Prussia, a German kingdom that competed with Austria for dominance in the German Confederation. During his early days in politics, the conservative Bismarck had held deep-seated apprehensions that unification would lead to the demise of Prussia's identity, and he had thus accepted Austria's prevailing supremacy within the German Confederation. With the passage of time, though, Bismarck came to consider Prussia's deference to Austria humiliating and feared his nation would lose its standing within the region. He eventually became the leading advocate of unification, embracing a vision of a new German state dominated by Prussia. Bismarck was a practitioner of what is known as realpolitik, a pragmatic approach to diplomacy and statecraft that focuses on strategic objectives and national interest at the expense of ideological and ethical considerations. Bismarck repeatedly demonstrated his mastery of realpolitik in his efforts to achieve his political objectives. First, upon taking power, Bismarck found himself in conflict with the liberal majority in the lower house of Prussia's legislature over issues related to the nation's military budget. He soon realized, however, that a diplomatic dispute with Denmark had potential as both a distraction from the budget issue and a means to advance the cause of German unification. At the time, Denmark was attempting to incorporate a section of Schleswig-Holstein, a member of the German Confederation, into its territory. Though even the Prussian monarch admitted that his nation had no legitimate claims on Schleswig-Holstein, Bismarck saw an opportunity to exploit outrage regarding Denmark's actions among members of the German Confederation, and he launched a successful military campaign that wrested control of it from Denmark, expanding both Prussian territory and influence. Two years later, Bismarck again utilized realpolitik, isolating rival Austria diplomatically to allow Prussia to go to war with it without bringing powers like France and Russia into the conflict. This second Prussian triumph allowed Prussia to annex more territory and relegated Austria to the status of a second-rate state that was so focused on internal issues that it was no longer a threat. In the wake of the conflict, the North German Confederation, a relatively unified collection of twenty-two states, was formed, with Prussia playing a dominant role. Both these actions served to increase popular support for the formation of a German state and undermine liberal opposition to Prussia's military expansion. While the North German Confederation was an important step toward unification, it could not become a reality without the southern German states, which were hesitant to enter into a political union. Bismarck, however, realized that the southern German states' treaties specifying military cooperation with Prussia could be manipulated to overcome their reluctance. Therefore, he utilized realpolitik again, resorting to purposely inflaming tensions with France, the common enemy of the German states. He did so by crafting a diplomatic incident, selectively modifying key phrases and omitting context in an important diplomatic telegram, deliberately provoking outrage in France, all the while insisting that he was  ...
#   'He began to see that cooperating with it on a temporary basis could be the key to achieving a united German nation.',
#   'He realized that for the German Confederation to succeed, Austria would need to become a member.',
#   'He came to believe that Prussia could not tolerate Austria being more powerful because it hurt Prussian pride and could weaken it politically.',
#   'He formed the opinion that Prussia needed to be less aggressive toward Austria in order to preserve peace.',
#   'Although Prussia did not have a valid claim on Schleswig-Holstein, Bismarck began a war over it in order to improve his political position.',
#   "Bismarck intentionally angered other members of the German Confederation due to the demands of Prussia's monarch.",
#   'Against the wishes of other European nations, he helped to improve the position of Austria within the North German Confederation.',
#   "He used the opportunity of unification to gain support from France for Prussia's agenda.",
#   'convincing them that the treaties they had signed with Prussia were not sufficient to protect them if they were attacked by France.',
#   "making them believe that Prussia's treaty with France was actually highly unfavorable to their interests.",
#   "tricking France into attacking Prussia so that their alliances would cause them to join the fighting on Prussia's side.",
#   'reflects the commonly held idea at the time that the peace between Germany and France would be a long-lasting one.',
#   'is evidence that Bismarck actually had the best interests of the southern German states in mind when he unified Germany.',
#   "shows that Bismarck failed to understand how much holding the ceremony there would affect Germany's future relations with France.",
# ...
#   'The newest circles are chosen by the females.',
#   'The circles are always made in the softest sand.',
#   'Males make new circles when trying to find new partners.',
#   "We have to make a group presentation next Wednesday, and you are my partner. Mrs. Jones asked us to choose a type of bird and then search for information about how these birds live and what they eat. I chose penguins because I'm really interested in them. I hope that's OK with you. We started writing in class. I finished writing about where penguins live. I have also started to prepare pictures for our presentation. We have to have at least ten pictures for the presentation. I will prepare the first five, and you can do the rest. Can you research the food the penguins eat? You need to write around 150 words in addition to preparing pictures for the presentation. Let's meet on Monday so we can work together. I am free after school because there is no soccer practice that day. Can you meet me in the library? Don't forget your computer. We need to show our work to Mrs. Jones before Wednesday's presentation. See you soon, Leo",
#   'Circles in the Sand In 1995, divers swimming in the ocean near southern Japan discovered something unusual. They saw large circles drawn in the sand at the bottom of the sea. The divers did not know what had caused these circles. However, the mystery was eventually solved by some scientists who saw the circles being drawn. The artist was a male fish called a puffer fish. He was using different parts of his body to create the circles. When his work was complete, a female came and laid her eggs in the center. The puffer fish is not the only animal that creates beautiful art. A bird called the bowerbird is another example. They gather colorful objects to build a structure called a "bower." This structure looks like a nest. Other animals perform "art" that looks like songs or dances. These animals do not make art for pleasure. The purpose is to attract a partner. There is a risk for animals doing this because it can attract attention from dangerous animals. One idea is that the circles provide ideal conditions for puffer fish eggs to grow. Sadly, the circles do not last long. They always make a new circle each time they look for a partner.',
#   'He has chosen the topic of the science presentation.',
#   'He thinks he will be absent from school on Wednesday.',
#   'She should think about what kind of bird to write about.',
#   'She should ask Mrs. Jones who her partner is going to be.',
#   'He has chosen which photographs they will use.',
#   'He has written his part of the presentation.',
#   'He has made ten slides to show in their class.',
#   'He has researched more information about food.',
#   'meet him after he finishes soccer practice.',
#   'go to the library early before school.',
#   'bring her computer on Monday.',
#   'speak to the teacher as soon as possible.',
#   'a new type of sea creature called a puffer fish.',
#   'strange circle patterns at the bottom of the ocean.',
#   'marks in the sand that were made by the motion of seawater.',
#   'fish eggs that Japanese scientists had never seen before.',
#   'To avoid other dangerous animals living nearby.',
#   'To make other animals interested in becoming their partner.',
#   'They are trying to improve their creative skills.',
#   'They enjoy the pleasure of making nests to live in.',
#   'better at creating art than males.',
#   'stronger than most other partners they can find.',
#   'the ones who select partners.',
#   'chosen by stronger and healthier male partners.',
#   'Only one puffer fish egg can fit in a circle.',
#   'The newest circles are chosen by the females.',
#   'The circles are always made in the softest sand.',
#   'Males make new circles when trying to find new partners.',
#   "We have to make a group presentation next Wednesday, and you are my partner. Mrs. Jones asked us to choose a type of bird and then search for information about how these birds live and what they eat. I chose penguins because I'm really interested in them. I hope that's OK with you. We started writing in class. I finished writing about where penguins live. I have also started to prepare pictures for our presentation. We have to have at least ten pictures for the presentation. I will prepare the first five, and you can do the rest. Can you research the food the penguins eat? You need to write around 150 words in addition to preparing pictures for the presentation. Let's meet on Monday so we can work together. I am free after school because there is no soccer practice that day. Can you meet me in the library? Don't forget your computer. We need to show our work to Mrs. Jones before Wednesday's presentation. See you soon, Leo",
#   'In 1995, divers swimming in the ocean near southern Japan discovered something unusual. They saw large circles drawn in the sand at the bottom of the sea. The divers did not know what had caused these circles. However, the mystery was eventually solved by some scientists who saw the circles being drawn. The artist was a male fish called a puffer fish. He was using different parts of his body to create the circles. When his work was complete, a female came and laid her eggs in the center. The puffer fish is not the only animal that creates beautiful art. A bird called the bowerbird is another example. They gather colorful objects to build a structure called a "bower." This structure looks like a nest. Other animals perform "art" that looks like songs or dances. These animals do not make art for pleasure. The purpose is to attract a partner. There is a risk for animals doing this because it can attract attention from dangerous animals. It is almost always males that perform these behaviors rather than females. Instead, the female watches the male perform and decides whether to choose him as a partner. That is because scientists believe that the quality of a male animal\'s art or performance is often a good way for the female to select the healthiest male. Females want to choose healthy males because their babies will be stronger and healthier, too. In the case of the puffer fish, scientists still do not really know how females choose the best males. Perhaps they choose the most beautiful circle or the circle on the softest sand. One idea is that the circles provide ideal conditions for puffer fish eggs to grow. Sadly, the circles do not last long. They always make a new circle each time they look for a partner.',
#   'What will the girl do this weekend?',
#   "Visit her grandma's house.",
#   'Go to a wedding in the mountains.',
#   'Plan a trip to a lake with the boy.',
#   'Play table tennis with her aunt.',
#   'What will the man do next?',
#   'Take his son to a class.',
#   'Make some chicken soup.',
#   'Clean the refrigerator.',
#   'Take out the garbage.',
#   'Why is the man at the department store?',
#   'He has to return some clothes.',
#   'He needs some new shoes.',
#   'He has to buy a present.',
#   'He heard about a sale.',
#   'What does Greg want to do for his birthday?',
#   'Get a new music CD.',
#   'Have a party at home.',
#   'Play in a concert.',
#   'Go to a rock concert.',
#   'Why is the woman upset?',
#   'She wanted to rent the space.',
#   'She did not have time to get coffee.',
#   'She liked to study at the coffee shop.',
#   'She could not find the newspaper.',
#   'Why is the man calling the restaurant?',
#   "To ask about the restaurant's menu.",
#   'To get directions to the restaurant.',
#   'To make a reservation for dinner.',
#   'To order some special food items.',
#   'What does Mary hope to do?',
#   'Study to be a teacher.',
#   'Become an artist.',
#   'Make her own brushes.',
#   'Win a prize in a contest.',
#   'What is the main purpose of the workshop?',
#   'To keep people caught by the police.',
#   'To make musical instruments.',
#   'To plan important events.',
#   'To design fashion items.',
#   'Which one is the woman talking about?',
#   'The one for ice cream.',
#   'The one for vegetable soup.',
#   'The one for meat stew.',
#   'The one for chocolate cake.',
#   'What does the store advertisement say?',
#   'An offer is only available for one day.',
#   'The store will close soon.',
#   'All goods are only $20 today.',
#   'Only a few soap and shampoo products are left.',
#   'What is Nina nervous about?',
#   'Finding an interesting topic.',
#   'Asking her brother about science.',
#   'Giving a presentation to her class.',
#   'Going to school by herself.',
#   'What will the girl do this weekend?',
#   "Visit her grandma's house.",
#   'Go to a wedding in the mountains.',
#   'Plan a trip to a lake with the boy.',
#   'Play table tennis with her aunt.',
#   'What will the man do next?',
#   'Take his son to a class.',
#   'Make some chicken soup.',
#   'Clean the refrigerator.',
#   'Take out the garbage.',
#   'Why is the man at the department store?',
#   'He has to return some clothes.',
#   'He needs some new shoes.',
#   'He has to buy a present.',
#   'He heard about a sale.',
#   'What does Greg want to do for his birthday?',
#   'Get a new music CD.',
#   'Have a party at home.',
#   'Play in a concert.',
#   'Go to a rock concert.',
#   'Why is the woman upset?',
#   'She wanted to rent the space.',
#   'She did not have time to get coffee.',
#   'She liked to study at the coffee shop.',
#   'She could not find the newspaper.',
#   'Why is the man calling the restaurant?',
#   "To ask about the restaurant's menu.",
#   'To get directions to the restaurant.',
#   'To make a reservation for dinner.',
#   'To order some special food items.',
#   'What does Mary want to do in the future?',
#   'Study to be a teacher.',
#   'Become an artist.',
#   'Make her own brushes.',
#   'Win a prize in a contest.',
#   'What will the new building be used for?',
#   'To keep people caught by the police.',
#   'To make musical instruments.',
#   'To plan important events.',
#   'To design fashion items.',
#   'Which bowl does the man want to use?',
#   'The one for ice cream.',
#   'The one for vegetable soup.',
#   'The one for meat stew.',
#   'The one for chocolate cake.',
#   "What is true about the shop's sale?",
#   'An offer is only available for one day.',
#   'The store will close soon.',
#   'All goods are only $20 today.',
#   'Only a few soap and shampoo products are left.',
#   'What is Nina nervous about?',
#   'Finding an interesting topic.',
#   'Asking her brother about science.',
#   'Giving a presentation to her class.',
#   'Going to school by herself.',
#   'What did Sarah make a video about last weekend?',
#   'How to play the piano.',
#   'How to cook Italian food.',
#   'How to choose cool clothes.',
#   'How to speak English.',
#   'What is one thing that we learn about oats?',
#   'They are a kind of vegetable.',
#   'They were grown first in America.',
#   'They grow well in cold places.',
#   'They are used only to feed animals.',
#   'Why was Keita disappointed?',
#   'It rained on the day of the concert.',
#   'He could not get tickets.',
#   'Amy did not want to go.',
#   'The concert was cancelled.',
#   'Why is this announcement being made?',
#   'To say the bus will be late.',
#   'To inform about the ticket price.',
#   'To talk about a free tour.',
#   'To request lost property.',
#   'What will Robert do this afternoon?',
#   'Play in a basketball game.',
#   'Coach his team.',
#   'Watch his team play.',
#   'Go home early.',
#   'Why is the man at the department store?',
#   'He has to return some clothes.',
#   'He needs some new shoes.',
#   'He has to buy a present.',
#   'He heard about a sale.',
#   'What does Greg want to do for his birthday?',
#   'Get a new music CD.',
#   'Have a party at home.',
#   'Play in a concert.',
#   'Go to a rock concert.',
#   'Why is the woman upset?',
#   'She wanted to rent the space.',
#   'She did not have time to get coffee.',
#   'She liked to study at the coffee shop.',
#   'She could not find the newspaper.',
#   'Why is the man calling the restaurant?',
#   "To ask about the restaurant's menu.",
#   'To get directions to the restaurant.',
#   'To make a reservation for dinner.',
#   'To order some special food items.',
#   'What does Mary want to do?',
#   'Study to be a teacher.',
#   'Become an artist.',
#   'Make her own brushes.',
#   'Win a prize in a contest.',
#   'What is one job that does not usually take place in a jail?',
#   'To keep people caught by the police.',
#   'To make musical instruments.',
#   'To plan important events.',
#   'To design fashion items.',
#   'Which spoon would you use for vegetable soup?',
#   'The one for ice cream.',
#   'The one for vegetable soup.',
#   'The one for meat stew.',
#   'The one for chocolate cake.',
#   'What can be said about the store?',
#   'An offer is only available for one day.',
#   'The store will close soon.',
#   'All goods are only $20 today.',
#   'Only a few soap and shampoo products are left.',
#   'What is Nina nervous about?',
#   'Finding an interesting topic.',
#   'Asking her brother about science.',
#   'Giving a presentation to her class.',
#   'Going to school by herself.',
#   'What is one thing the girl says about the zoo?',
#   'It has a new dolphin.',
#   'It will have a special show.',
#   'It will be closing next week.',
#   'It has few animals.',
#   'What does the customer ask the waiter to do?',
#   'Heat up her plate.',
#   'Give her some more pasta.',
#   'Tell her about a new dish.',
#   'Bring her the check.',
#   'What is one thing Emily says about her trip to New York?',
#   'She could not leave the hotel.',
#   'She did not go to any museums.',
#   'She went on a sightseeing tour.',
#   'She stayed outside of the city.',
#   'What do we learn about the man?',
#   'He wants a salad with his sandwich.',
#   'He needs to leave the restaurant soon.',
#   'He is ordering for a friend.',
#   'He feels very hungry today.',
#   'What will the girl do this weekend?',
#   "Visit her grandma's house.",
#   'Go to a wedding in the mountains.',
#   'Plan a trip to a lake with the boy.',
#   'Play table tennis with her aunt.',
#   'What will the man do next?',
#   'Take his son to a class.',
#   'Make some chicken soup.',
#   'Clean the refrigerator.',
#   'Take out the garbage.',
#   'Why is the man at the department store?',
#   'He has to return some clothes.',
#   'He needs some new shoes.',
#   'He has to buy a present.',
#   'He heard about a sale.',
#   'What does Greg want to do for his birthday?',
#   'Get a new music CD.',
#   'Have a party at home.',
#   'Play in a concert.',
#   'Go to a rock concert.',
#   'Why is the woman upset?',
#   'She wanted to rent the space.',
#   'She did not have time to get coffee.',
#   'She liked to study at the coffee shop.',
#   'She could not find the newspaper.',
#   'Why is the man calling the restaurant?',
#   "To ask about the restaurant's menu.",
#   'To get directions to the restaurant.',
#   'To make a reservation for dinner.',
#   'To order some special food items.',
#   'What does Mary hope to do?',
#   'Study to be a teacher.',
#   'Become an artist.',
#   'Make her own brushes.',
#   'Win a prize in a contest.',
#   'What does the job involve?',
#   'To keep people caught by the police.',
#   'To make musical instruments.',
#   'To plan important events.',
#   'To design fashion items.',
#   'Which dish does the woman want?',
#   'The one for ice cream.',
#   'The one for vegetable soup.',
#   'The one for meat stew.',
#   'The one for chocolate cake.',
#   'What does the sign mean?',
#   'An offer is only available for one day.',
#   'The store will close soon.',
#   'All goods are only $20 today.',
#   'Only a few soap and shampoo products are left.',
#   'What is Nina nervous about?',
#   'Finding an interesting topic.',
#   'Asking her brother about science.',
#   'Giving a presentation to her class.',
#   'Going to school by herself.',
#   'started opening later',
#   'got some new staff',
#   'bought some new chairs',
#   'changed our menu',
#   'draw a picture of a plant',
#   'answer questions in my textbook',
#   'get some information about space',
#   'measure the size of my head',
#   'you give me 25 percent off a new car',
#   'you print a new receipt for me',
#   'I buy a new suit for half price',
#   'I get a new TV for less money',
#   'meetings to go to',
#   'homework to do',
#   'club activities',
#   "doctor's appointments",
#   'that she should stay home',
#   'that they could make one',
#   'to wear a green one',
#   ...]}

# %%
import count
import importlib
importlib.reload(count)

all_unigrams = set()
all_phrases = set()

counts: dict[str, count.CountResult] = {}
for grade, texts in tqdm(wordlist_by_grade.items()):
    grade_count = counts[grade] = count.count_collocations(
        texts,
        nlp=nlp,
        n_process=4,
        include_edges=False,
    )
    all_unigrams.update(grade_count.unigram)
    all_phrases.update(grade_count.phrase)

all_unigrams = list(sorted(all_unigrams))
all_phrases = list(sorted(all_phrases))

counts_array = dict[str, (np.ndarray[int], np.ndarray[int])]()

for grade, grade_count in counts.items():
    unigram_counts = np.array([grade_count.unigram.get(word, 0) for word in all_unigrams], dtype=int)
    phrase_counts = np.array([grade_count.phrase.get(phrase, 0) for phrase in all_phrases], dtype=int)
    counts_array[grade] = (unigram_counts, phrase_counts)

counts_array
# Out:
# 100%|██████████| 7/7 [00:22<00:00,  3.25s/it]
# {'1': (array([1413,    4,    0, ...,    3,    0,    0], shape=(6349,)),
#   array([0, 0, 2, ..., 0, 0, 0], shape=(10193,))),
#  '5': (array([404,   0,   0, ...,   0,   4,   0], shape=(6349,)),
#   array([0, 0, 0, ..., 0, 0, 0], shape=(10193,))),
#  '2': (array([1420,    0,    0, ...,    0,    2,    6], shape=(6349,)),
#   array([0, 0, 0, ..., 0, 0, 2], shape=(10193,))),
#  '4': (array([1009,    0,    0, ...,    0,   11,    0], shape=(6349,)),
#   array([0, 0, 0, ..., 1, 0, 0], shape=(10193,))),
#  'pre1': (array([930,   1,   1, ...,   0,   0,   0], shape=(6349,)),
#   array([0, 0, 0, ..., 0, 0, 0], shape=(10193,))),
#  '3': (array([1410,    0,    0, ...,    0,    9,    0], shape=(6349,)),
#   array([1, 0, 0, ..., 0, 1, 0], shape=(10193,))),
#  'pre2': (array([1262,    0,    0, ...,    0,    5,    0], shape=(6349,)),
#   array([0, 1, 0, ..., 0, 0, 0], shape=(10193,)))}

# %%
# カウントをスコアに変換
scores_by_grade: dict[str, (
    np.ndarray[float], # unigram
    np.ndarray[float] # phrase
)] = {}

grades = [
    '1',
    'pre1',
    '2',
    'pre2',
    '3',
    '4',
    '5',
]

MIN_UNIGRAM_CH = 3
MIN_PHRASE_CH = 2

A = 1
for grade, (unigram_counts, phrase_counts) in counts_array.items():
    # 下位の級を合算
    lower_grades = grades[grades.index(grade)+1:]

    # 下位の級の確率を計算
    unigram_cL = np.zeros(len(all_unigrams), dtype=int)
    phrase_cL = np.zeros(len(all_phrases), dtype=int)
    unigram_nL = 0 # nL ... 下位の級で出現した総 unigram 回数
    phrase_nL = 0 # nL ... 下位の級で出現した総 phrase 回数
    for lg in lower_grades:
        unigram_counts_l, phrase_counts_l = counts_array[lg]
        unigram_cL += unigram_counts_l
        phrase_cL += phrase_counts_l
        unigram_nL += counts[lg].unigram_n
        phrase_nL += counts[lg].phrase_n

    unigram_cH = unigram_counts
    phrase_cH = phrase_counts
    unigram_nH = counts[grade].unigram_n
    phrase_nH = counts[grade].phrase_n

    unigram_V = len(all_unigrams)
    phrase_V = len(all_phrases)

    unigram_pH = np.log((unigram_cH + A) / (unigram_nH + A * unigram_V)) # 上位の級の確率
    phrase_pH = np.log((phrase_cH + A) / (phrase_nH + A * phrase_V)) # 上位の級の確率
    unigram_pL = np.log((unigram_cL + A) / (unigram_nL + A * unigram_V)) # 下位の級の確率
    phrase_pL = np.log((phrase_cL + A) / (phrase_nL + A * phrase_V)) # 下位の級の確率

    unigram_scores = unigram_pH - unigram_pL # スコア計算
    phrase_scores = phrase_pH - phrase_pL # スコア計算

    scores_by_grade[grade] = (
        unigram_scores,
        phrase_scores,
    )

# %%
# rank で unigram と phrase を合わせる

merged_words = []
merged_words.extend(all_unigrams)
merged_words.extend(all_phrases)

merged_ranks_by_grade: dict[str, np.ndarray[float]] = {}


for grade, (unigram_scores, phrase_scores) in scores_by_grade.items():
    unigram_sorted_indices = np.argsort(unigram_scores)[::-1]
    phrase_sorted_indices = np.argsort(phrase_scores)[::-1]

    unigram_rank = np.empty(len(all_unigrams), dtype=int)
    unigram_rank[unigram_sorted_indices] = np.arange(1, len(all_unigrams)+1)
    phrase_rank = np.empty(len(all_phrases), dtype=int)
    phrase_rank[phrase_sorted_indices] = np.arange(1, len(all_phrases)+1)

    n_unigrams = len(all_unigrams)
    n_phrases = len(all_phrases)

    unigram_normed_ranks = (n_unigrams - unigram_rank + 0.5) / n_unigrams
    phrase_normed_ranks = (n_phrases - phrase_rank + 0.5) / n_phrases

    merged_scores = np.concatenate([unigram_normed_ranks, phrase_normed_ranks])
    merged_ranks_by_grade[grade] = merged_scores

merged_ranks_by_grade
# Out:
# {'1': array([0.1985352 , 0.77468893, 0.39588912, ..., 0.45516531, 0.45526342,
#         0.27092122], shape=(16542,)),
#  '5': array([0.99960624, 0.64017956, 0.64002205, ..., 0.33115864, 0.33125674,
#         0.33135485], shape=(16542,)),
#  '2': array([0.13962829, 0.63151677, 0.62411403, ..., 0.23256156, 0.19606593,
#         0.91803198], shape=(16542,)),
#  '4': array([0.91423846, 0.33194204, 0.32690187, ..., 0.93598548, 0.64039046,
#         0.32674384], shape=(16542,)),
#  'pre1': array([0.12954796, 0.81753032, 0.77909907, ..., 0.3846267 , 0.38472481,
#         0.22814677], shape=(16542,)),
#  '3': array([0.07426366, 0.36092298, 0.35950543, ..., 0.03634847, 0.9063573 ,
#         0.7668498 ], shape=(16542,)),
#  'pre2': array([0.08875413, 0.63498189, 0.25602457, ..., 0.13004022, 0.11630531,
#         0.41337192], shape=(16542,))}

# %%
# ソート
vocablist_by_grade: dict[str, list[(str, float)]] = {}
for grade, merged_scores in merged_ranks_by_grade.items():
    sorted_indices = np.argsort(merged_scores)[::-1]  # スコアの高い順にソート
    sorted_vocablist = [
        (merged_words[i], merged_scores[i].item())
        for i in sorted_indices
    ]
    vocablist_by_grade[grade] = sorted_vocablist

# %%
# 最終的に csv に保存
# 単語, 型(unigram or phrase), 1級スコア, pre1スコア, ..., 5級スコア, 1級カウント, ..., 5級カウント, 1級ランク, ..., 5級ランク
import os

rows = []
for i, vocab in enumerate(merged_words):
    is_unigram = i < len(all_unigrams)

    scores = {
        grade: scores_by_grade[grade][0 if is_unigram else 1][i if is_unigram else i - len(all_unigrams)].item()
        for grade in grades
    }
    counts = {
        grade: counts_array[grade][0 if is_unigram else 1][i if is_unigram else i - len(all_unigrams)].item()
        for grade in grades
    }
    ranks = {
        grade: merged_ranks_by_grade[grade][i].item()
        for grade in grades
    }
    
    row = {
        'vocab': vocab,
        'type': 'unigram' if is_unigram else 'phrase',
    }
    for grade in grades:
        row[f'score_{grade}'] = scores[grade]
    for grade in grades:
        row[f'count_{grade}'] = counts[grade]
    for grade in grades:
        row[f'rank_{grade}'] = ranks[grade]
    rows.append(row)

df = pd.DataFrame(rows)
target_path = '../../data/wordlist-scores/vocablist_by_grade.csv'
os.makedirs(os.path.dirname(target_path), exist_ok=True)
df.to_csv(target_path, index=False)
